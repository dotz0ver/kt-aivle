# %% [markdown]
# # **종합실습 단변량 분석**

# %% [markdown]
# ## **1.비즈니스 시나리오**

# %% [markdown]
# ![](https://cdn.images.express.co.uk/img/dynamic/24/590x/child-car-seat-986556.jpg?r=1532946857754)

# %% [markdown]
# * 고객사는 카시트를 판매하는 회사 입니다.
# * 최근 매출 하락에 대해 각 부서가 파악한 원인 다음과 같습니다.
#     * 최근에 경쟁사와의 가격 경쟁력이 하락하고 있고, 광고비용이 적절하게 집행되지 않음
#     * 너무 국내 시장에 집중됨.
#     * 지역마다의 구매력을 제대로 파악하지 못하고 있음.
# >
# * 그러나 이러한 분석은 데이터에 근거하고 있는지 의문이 듭니다.
# * 이 문제를 해결하고자 프로젝트 팀이 빌딩되었습니다.
# * 여러분은 이 프로젝트팀에 데이터분석전문가 이자 AI 개발자로 참여하고 있습니다.
# * 드디어 AIVLE 과정에서 갈고 닦은 실력을 발휘할 기회가 주어졌습니다.
# * 자, 이제 단변량 분석을 통해 비즈니스 인사이트를 도출해 봅시다!

# %% [markdown]
# ## **2.환경준비**

# %% [markdown]
# ### **(1) 라이브러리 불러오기**

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### **(2) 데이터 로딩 : 카시트 판매량 데이터**

# %% [markdown]
# |	변수명	|	설명	|	구분	|
# |----|----|----|
# |	**Sales** 	|	 각 지역 판매량(단위 : 1000개)	|	Target	|
# |	**CompPrice** 	|	 경쟁사 가격(단위 : 달러)	|	feature	|
# |	**Income** 	|	 지역 평균 소득(단위 : 1000달러)	|	feature	|
# |	**Advertising** 	|	 각 지역, 회사의 광고 예산(단위 : 1000달러)	|	feature	|
# |	**Population** 	|	 지역 인구수(단위 : 1000명)	|	feature	|
# |	**Price** 	|	 자사 지역별 판매가격	|	feature	|
# |	**ShelveLoc** 	|	 진열상태	|	feature	|
# |	**Age** 	|	 지역 인구의 평균 연령	|	feature	|
# |	**Urban** 	|	 도심 지역 여부(Yes,No)	|	feature	|
# |	**US** 	|	 매장이 미국에 있는지 여부(Yes,No)	|	feature	|

# %%
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/Carseats2.csv'
data = pd.read_csv(path)
data.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#   Urban   US
# 0   Yes  Yes
# 1   Yes  Yes
# 2   Yes  Yes
# 3   Yes  Yes
# 4   Yes   No

# %% [markdown]
# ## **3.단변량분석 : 숫자형 변수**

# %% [markdown]
# * 숫자형변수를 분석하는 함수를 생성합시다.

# %%
def eda_1_num(data, var, bins = 30):

    # 기초통계량
    print('<< 기초통계량 >>')
    display(data[[var]].describe().T)
    print('=' * 100)

    # 시각화
    print('<< 그래프 >>')
    plt.figure(figsize = (10,6))

    plt.subplot(2,1,1)
    sns.histplot(data[var], bins = bins, kde = True)
    plt.grid()

    plt.subplot(2,1,2)
    sns.boxplot(x = data[var])
    plt.grid()
    plt.show()

# %% [markdown]
# ### **(1) Sales (Target)**

# %%
var = 'Sales'

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %% [markdown]
# * 각 지역 판매량(단위 : 1000개)
# * Target

# %% [markdown]
# 2) 기초통계량 및 분포확인

# %%
eda_1_num(data, var)
# Out:
# << 기초통계량 >>
#        count      mean       std  min   25%   50%   75%    max
# Sales  400.0  7.496325  2.824115  0.0  5.39  7.49  9.32  16.27
# ====================================================================================================
# << 그래프 >>

# %% [markdown]
# 3) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %% [markdown]
# * 대부분의 판매량이 5천개 ~ 만개 사이

# %% [markdown]
# 4) 추가 분석해 볼 사항이 있나요?

# %% [markdown]
# * 판매량 구간을 0 ~ 4천, 4천 ~ 1만, 1만 이상 으로 구분해서 분석해 볼 필요 있음.

# %% [markdown]
# ### **(2) CompPrice**

# %%
var = 'CompPrice'

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %%
# 경쟁사의 카시트 가격

# %% [markdown]
# 2) 기초통계량 및 분포확인

# %%
eda_1_num(data, var)
# Out:
# << 기초통계량 >>
#            count     mean        std   min    25%    50%    75%    max
# CompPrice  400.0  124.975  15.334512  77.0  115.0  125.0  135.0  175.0
# ====================================================================================================
# << 그래프 >>

# %% [markdown]
# 3) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %% [markdown]
# - 가격 책정 전략: 대부분의 제품이 115~135 사이의 가격대에 집중되어 있으므로, 이 범위에서의 경쟁이 치열할 가능성이 높습니다. 신규 제품 출시 시 이 가격대를 중심으로 경쟁력을 확보하거나, 차별화된 프리미엄 제품으로 최고가 전략을 고려할 수 있습니다.
# - 이상치 제품군의 활용: 가격이 극단적으로 낮거나 높은 제품이 있으므로, 이 제품군에 대한 별도의 마케팅 전략이 필요할 수 있습니다. 예를 들어, 저가 제품은 프로모션용, 고가 제품은 프리미엄 시장을 타겟팅하는 전략을 사용할 수 있습니다.

# %% [markdown]
# 4) 추가 분석해 볼 사항이 있나요?

# %% [markdown]
# ### **(3) Income**

# %%
var =

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %% [markdown]
# 2) 기초통계량 및 분포확인

# %% [markdown]
# 3) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %% [markdown]
# 4) 추가 분석해 볼 사항이 있나요?

# %% [markdown]
# ### **(4) Advertising**

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %% [markdown]
# 2) 기초통계량 및 분포확인

# %% [markdown]
# 3) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %% [markdown]
# 4) 추가 분석해 볼 사항이 있나요?

# %% [markdown]
# ### **(5) Population**

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %% [markdown]
# 2) 기초통계량 및 분포확인

# %% [markdown]
# 3) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %% [markdown]
# 4) 추가 분석해 볼 사항이 있나요?

# %% [markdown]
# ### **(6) Price**

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %% [markdown]
# 2) 기초통계량 및 분포확인

# %% [markdown]
# 3) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %% [markdown]
# 4) 추가 분석해 볼 사항이 있나요?

# %% [markdown]
# ### **(7) Age**

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %% [markdown]
# 2) 기초통계량 및 분포확인

# %% [markdown]
# 3) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %% [markdown]
# 4) 추가 분석해 볼 사항이 있나요?

# %% [markdown]
# ## **4.단변량분석 : 범주형 변수**

# %% [markdown]
# * 함수 생성

# %%
def eda_1_cat(data, var) :
    t1 = data[var].value_counts()
    t2 = data[var].value_counts(normalize = True)
    t3 = pd.concat([t1, t2], axis = 1)
    t3.columns = ['count','ratio']
    display(t3)
    sns.countplot(x = var, data = data)
    plt.show()

# %% [markdown]
# ### **(1) ShelveLoc**

# %%
var = 'ShelveLoc'

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %% [markdown]
# * 매장 진열상태

# %% [markdown]
# 2) 기초통계량(수치화)

# %%
eda_1_cat(data, var)

# %% [markdown]
# 3) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %% [markdown]
# * 진열 상태가 중간 정도 가 54%

# %% [markdown]
# 4) 추가 분석해 볼 사항이 있나요?

# %% [markdown]
# * 진열상태에 따른 판매량 차이
# * 지역, 인구수와 진열 상태 관계 비교

# %% [markdown]
# ### **(2) Urban**

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %% [markdown]
# 2) 기초통계량(수치화)

# %% [markdown]
# 3) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %% [markdown]
# 4) 추가 분석해 볼 사항이 있나요?

# %% [markdown]
# ### **(3) US**

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %% [markdown]
# 2) 기초통계량(수치화)

# %% [markdown]
# 3) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %% [markdown]
# 4) 추가 분석해 볼 사항이 있나요?
