# %% [markdown]
# # **데이터프레임 결합**

# %% [markdown]
# ## **1.환경준비**

# %% [markdown]
# * 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# * 데이터 가져오기

# %%
sales = pd.read_csv("https://raw.githubusercontent.com/DA4BAM/dataset/master/ts_sales_simple.csv")

sales1 = sales.loc[sales['Store_ID']==1]
sales2 = sales.loc[sales['Store_ID']==2]
sales5 = sales.loc[sales['Store_ID']==5]
sales11 = sales.loc[sales['Store_ID']==11]

products = pd.read_csv("https://raw.githubusercontent.com/DA4BAM/dataset/master/ts_product_master.csv")
stores = pd.read_csv("https://raw.githubusercontent.com/DA4BAM/dataset/master/ts_store_master.csv")

# %%
sales1.head()
# Out:
#    Order_ID        Date  Store_ID  Qty  Product_ID
# 0         3  2013-01-01         1  0.0           3
# 1         5  2013-01-01         1  0.0           5
# 2         7  2013-01-01         1  0.0           7
# 3         8  2013-01-01         1  0.0           8
# 4        10  2013-01-01         1  0.0          10

# %%
products.head()
# Out:
#    Product_ID Product_Code      SubCategory         Category  LeadTime  Price
# 0          20        HG001  Gardening Tools  Household Goods         2     50
# 1          27        HH001  Home Appliances  Household Goods         2    150
# 2          16        HK001          Kitchen  Household Goods         2     23
# 3          15        HK002          Kitchen  Household Goods         2     41
# 4          32        GS001          Seafood          Grocery         3     34

# %%
stores.head()
# Out:
#    Store_ID           City      State  Store_Type
# 0         1     Saint Paul  Minnesota           4
# 1         2     Saint Paul  Minnesota           4
# 2         3     Saint Paul  Minnesota           4
# 3         4     Saint Paul  Minnesota           4
# 4         5  Oklahoma City   Oklahoma           4

# %% [markdown]
# ## **2.결합1 : 붙이기 concat()**

# %% [markdown]
# * 데이터를 생성해 봅시다.

# %%
df1 = pd.DataFrame({'A':[10,25], 'B':[15,30]})
df2 = pd.DataFrame({'A':[20,30, 50], 'C':[35,30, 40]})
df2.drop([1], inplace = True)

display(df1)
display(df2)
# Out:
#     A   B
# 0  10  15
# 1  25  30
#     A   C
# 0  20  35
# 2  50  40

# %% [markdown]
# ### **(1) 세로로 합치기 : axis = 0**

# %% [markdown]
# * join = 'inner'

# %%
pd.concat([df1, df2], axis = 0, join = 'inner')
# Out:
#     A
# 0  10
# 1  25
# 0  20
# 2  50

# %% [markdown]
# * join = 'outer'

# %%
pd.concat([df1, df2], axis = 0, join = 'outer')
# Out:
#     A     B     C
# 0  10  15.0   NaN
# 1  25  30.0   NaN
# 0  20   NaN  35.0
# 2  50   NaN  40.0

# %% [markdown]
# ### **(2) 가로로 합치기 : axis = 1**

# %% [markdown]
# * join = 'inner'

# %%
pd.concat([df1, df2], axis = 1, join = 'inner')
# Out:
#     A   B   A   C
# 0  10  15  20  35

# %% [markdown]
# * join = 'outer'

# %%
pd.concat([df1, df2], axis = 1, join = 'outer')
# Out:
#       A     B     A     C
# 0  10.0  15.0  20.0  35.0
# 1  25.0  30.0   NaN   NaN
# 2   NaN   NaN  50.0  40.0

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# [문1] sales1,2,5,11 데이터프레임을 하나로 합칩시다. 어떻게 합치는게 좋을까요?

# %%
sales1.head(3)
# Out:
#    Order_ID        Date  Store_ID  Qty  Product_ID
# 0         3  2013-01-01         1  0.0           3
# 1         5  2013-01-01         1  0.0           5
# 2         7  2013-01-01         1  0.0           7

# %%
sales2.head(3)
# Out:
#      Order_ID        Date  Store_ID  Qty  Product_ID
# 165       366  2013-01-01         2  0.0           3
# 166       368  2013-01-01         2  0.0           5
# 167       370  2013-01-01         2  0.0           7

# %%
temp = pd.concat([sales1, sales2, sales5, sales11], axis=0)
temp
# Out:
#        Order_ID        Date  Store_ID      Qty  Product_ID
# 0             3  2013-01-01         1    0.000           3
# 1             5  2013-01-01         1    0.000           5
# 2             7  2013-01-01         1    0.000           7
# 3             8  2013-01-01         1    0.000           8
# 4            10  2013-01-01         1    0.000          10
# ...         ...         ...       ...      ...         ...
# 24340     53548  2013-01-31        11   10.000          22
# 24341     53550  2013-01-31        11  641.507          24
# 24342     53553  2013-01-31        11    0.000          27
# 24343     53555  2013-01-31        11   27.000          29
# 24344     53558  2013-01-31        11   13.000          32
#
# [1860 rows x 5 columns]

# %% [markdown]
# [문2] (조금 어려운 문제!)
# 일별, 매장별 판매량 합계를 구해 봅시다.
# groupby, pd.concat 을 이용하여 다음과 같은 결과를 얻도록 코드를 작성해봅시다.
#
# * 힌트
#     * 1) sales1, 2, 5,11 로 부터 각각 일별 판매량 합계 집계하기
#         * 집계시 .agg() 를 이용하여 열이름 변경하거나, 집계후 열이름 변경하기
#     * 2) pd.concat 으로 가로로 합치기

# %%
temp.groupby(['Date', 'Store_ID'], as_index = False)['Qty'].sum()
# Out:
#            Date  Store_ID          Qty
# 0    2013-01-01         1     0.000000
# 1    2013-01-01         2     0.000000
# 2    2013-01-01         5     0.000000
# 3    2013-01-01        11     0.000000
# 4    2013-01-02         1  6760.782000
# ..          ...       ...          ...
# 119  2013-01-30        11  7744.136020
# 120  2013-01-31         1  4341.563000
# 121  2013-01-31         2  4862.804996
# 122  2013-01-31         5  5230.479000
# 123  2013-01-31        11  8367.902000
#
# [124 rows x 3 columns]

# %%
temp1 = sales1.groupby(['Date', 'Store_ID'], as_index=False)['Qty'].sum().rename({'Qty' : 'Qty_1'}, axis=1)
temp2 = sales2.groupby(['Date', 'Store_ID'], as_index=False)['Qty'].sum().rename({'Qty' : 'Qty_2'}, axis=1)
temp5 = sales5.groupby(['Date', 'Store_ID'], as_index=False)['Qty'].sum().rename({'Qty' : 'Qty_5'}, axis=1)
temp11 = sales11.groupby(['Date', 'Store_ID'], as_index=False)['Qty'].sum().rename({'Qty' : 'Qty_11'}, axis=1)

pd.concat([temp1, temp2, temp5, temp11], axis=1)
# Out:
#           Date  Store_ID        Qty_1        Date  Store_ID        Qty_2  \
# 0   2013-01-01         1     0.000000  2013-01-01         2     0.000000
# 1   2013-01-02         1  6760.782000  2013-01-02         2  9221.338001
# 2   2013-01-03         1  5348.384001  2013-01-03         2  6830.089000
# 3   2013-01-04         1  5390.445001  2013-01-04         2  6742.984000
# 4   2013-01-05         1  5787.839000  2013-01-05         2  8583.055000
# 5   2013-01-06         1  2007.194000  2013-01-06         2  9317.139000
# 6   2013-01-07         1  5639.396000  2013-01-07         2  6047.629000
# 7   2013-01-08         1  5131.128000  2013-01-08         2  5545.928020
# 8   2013-01-09         1  6198.154980  2013-01-09         2  6061.471020
# 9   2013-01-10         1  4309.750000  2013-01-10         2  5070.431000
# 10  2013-01-11         1  5053.745980  2013-01-11         2  5822.891982
# 11  2013-01-12         1  5073.569980  2013-01-12         2  7479.722000
# 12  2013-01-13         1  2482.635000  2013-01-13         2  9059.072000
# 13  2013-01-14         1  5192.406000  2013-01-14         2  5404.198000
# 14  2013-01-15         1  4774.043000  2013-01-15         2  5255.754000
# 15  2013-01-16         1  6210.563002  2013-01-16         2  6543.510000
# 16  2013-01-17         1  4544.486000  2013-01-17         2  5214.799020
# 17  2013-01-18         1  5419.165001  2013-01-18         2  6668.457000
# 18  2013-01-19         1  5447.259000  2013-01-19         2  8016.393000
# 19  2013-01-20         1  2153.939995  2013-01-20         2  8932.121020
# 20  2013-01-21         1  4784.614020  2013-01-21         2  6380.861000
# 21  2013-01-22         1  4922.417000  2013-01-22         2  5658.953001
# 22  2013-01-23         1  5770.343000  2013-01-23         2  6056.067000
# 23  2013-01-24         1  4559.193000  2013-01-24         2  4608.736000
# 24  2013-01-25         1  5144.064000  2013-01-25         2  6096.080000
# 25  2013-01-26         1  4820.926000  2013-01-26         2  7550.064982
# 26  2013-01-27         1  2242.990000  2013-01-27         2  8169.363000
# 27  2013-01-28         1  4484.428000  2013-01-28         2  5111.355000
# 28  2013-01-29         1  4285.201001  2013-01-29         2  5210.258000
# 29  2013-01-30         1  5634.577000  2013-01-30         2  5956.379000
# 30  2013-01-31         1  4341.563000  2013-01-31         2  4862.804996
#
#           Date  Store_ID        Qty_5        Date  Store_ID        Qty_11
# 0   2013-01-01         5     0.000000  2013-01-01        11      0.000000
# 1   2013-01-02         5  9404.229020  2013-01-02        11  16593.312000
# 2   2013-01-03         5  6932.685000  2013-01-03        11  11032.676040
# 3   2013-01-04         5  6567.938000  2013-01-04        11  10962.687002
# 4   2013-01-05         5  7276.800000  2013-01-05        11  13315.896000
# 5   2013-01-06         5  9578.077030  2013-01-06        11  14165.615050
# 6   2013-01-07         5  5729.203000  2013-01-07        11   9946.420000
# 7   2013-01-08         5  5716.248000  2013-01-08        11   9258.956000
# 8   2013-01-09         5  5352.507000  2013-01-09        11   8644.922000
# 9   2013-01-10         5  5319.121020  2013-01-10        11   8470.169000
# 10  2013-01-11         5  5786.585000  2013-01-11        11   7316.129000
# 11  2013-01-12         5  6246.480000  2013-01-12        11  10959.593000
# 12  2013-01-13         5  8299.981000  2013-01-13        11  10857.623960
# 13  2013-01-14         5  5398.938000  2013-01-14        11   7789.259030
# 14  2013-01-15         5  5528.819000  2013-01-15        11   8215.977970
# 15  2013-01-16         5  6147.083980  2013-01-16        11   7540.355000
# 16  2013-01-17         5  5109.820000  2013-01-17        11   7395.201000
# 17  2013-01-18         5  5043.555000  2013-01-18        11   7918.020000
# 18  2013-01-19         5  6228.933000  2013-01-19        11  11044.523000
# 19  2013-01-20         5  8204.085000  2013-01-20        11  11211.312000
# 20  2013-01-21         5  5511.559999  2013-01-21        11   9088.764040
# 21  2013-01-22         5  5426.481000  2013-01-22        11   7967.939000
# 22  2013-01-23         5  5624.662000  2013-01-23        11   7246.130000
# 23  2013-01-24         5  5053.194000  2013-01-24        11   7802.938000
# 24  2013-01-25         5  5591.837000  2013-01-25        11   7977.591980
# 25  2013-01-26         5  6232.117000  2013-01-26        11  10446.452000
# 26  2013-01-27         5  6562.350000  2013-01-27        11  10590.136000
# 27  2013-01-28         5  5595.128020  2013-01-28        11   8419.120000
# 28  2013-01-29         5  4720.338000  2013-01-29        11   6970.078000
# 29  2013-01-30         5  5071.153000  2013-01-30        11   7744.136020
# 30  2013-01-31         5  5230.479000  2013-01-31        11   8367.902000

# %%
agg_df_list = []
for i, df in enumerate([sales1, sales2, sales5, sales11]):
    agg_df = df.groupby(['Date', 'Store_ID'], as_index=False)['Qty'].sum().rename( {'Qty' : f'Qty_{i}'}, axis=1)
    agg_df_list.append(agg_df)

pd.concat(agg_df_list, axis=1, join='inner')
# Out:
#           Date  Store_ID        Qty_0        Date  Store_ID        Qty_1  \
# 0   2013-01-01         1     0.000000  2013-01-01         2     0.000000
# 1   2013-01-02         1  6760.782000  2013-01-02         2  9221.338001
# 2   2013-01-03         1  5348.384001  2013-01-03         2  6830.089000
# 3   2013-01-04         1  5390.445001  2013-01-04         2  6742.984000
# 4   2013-01-05         1  5787.839000  2013-01-05         2  8583.055000
# 5   2013-01-06         1  2007.194000  2013-01-06         2  9317.139000
# 6   2013-01-07         1  5639.396000  2013-01-07         2  6047.629000
# 7   2013-01-08         1  5131.128000  2013-01-08         2  5545.928020
# 8   2013-01-09         1  6198.154980  2013-01-09         2  6061.471020
# 9   2013-01-10         1  4309.750000  2013-01-10         2  5070.431000
# 10  2013-01-11         1  5053.745980  2013-01-11         2  5822.891982
# 11  2013-01-12         1  5073.569980  2013-01-12         2  7479.722000
# 12  2013-01-13         1  2482.635000  2013-01-13         2  9059.072000
# 13  2013-01-14         1  5192.406000  2013-01-14         2  5404.198000
# 14  2013-01-15         1  4774.043000  2013-01-15         2  5255.754000
# 15  2013-01-16         1  6210.563002  2013-01-16         2  6543.510000
# 16  2013-01-17         1  4544.486000  2013-01-17         2  5214.799020
# 17  2013-01-18         1  5419.165001  2013-01-18         2  6668.457000
# 18  2013-01-19         1  5447.259000  2013-01-19         2  8016.393000
# 19  2013-01-20         1  2153.939995  2013-01-20         2  8932.121020
# 20  2013-01-21         1  4784.614020  2013-01-21         2  6380.861000
# 21  2013-01-22         1  4922.417000  2013-01-22         2  5658.953001
# 22  2013-01-23         1  5770.343000  2013-01-23         2  6056.067000
# 23  2013-01-24         1  4559.193000  2013-01-24         2  4608.736000
# 24  2013-01-25         1  5144.064000  2013-01-25         2  6096.080000
# 25  2013-01-26         1  4820.926000  2013-01-26         2  7550.064982
# 26  2013-01-27         1  2242.990000  2013-01-27         2  8169.363000
# 27  2013-01-28         1  4484.428000  2013-01-28         2  5111.355000
# 28  2013-01-29         1  4285.201001  2013-01-29         2  5210.258000
# 29  2013-01-30         1  5634.577000  2013-01-30         2  5956.379000
# 30  2013-01-31         1  4341.563000  2013-01-31         2  4862.804996
#
#           Date  Store_ID        Qty_2        Date  Store_ID         Qty_3
# 0   2013-01-01         5     0.000000  2013-01-01        11      0.000000
# 1   2013-01-02         5  9404.229020  2013-01-02        11  16593.312000
# 2   2013-01-03         5  6932.685000  2013-01-03        11  11032.676040
# 3   2013-01-04         5  6567.938000  2013-01-04        11  10962.687002
# 4   2013-01-05         5  7276.800000  2013-01-05        11  13315.896000
# 5   2013-01-06         5  9578.077030  2013-01-06        11  14165.615050
# 6   2013-01-07         5  5729.203000  2013-01-07        11   9946.420000
# 7   2013-01-08         5  5716.248000  2013-01-08        11   9258.956000
# 8   2013-01-09         5  5352.507000  2013-01-09        11   8644.922000
# 9   2013-01-10         5  5319.121020  2013-01-10        11   8470.169000
# 10  2013-01-11         5  5786.585000  2013-01-11        11   7316.129000
# 11  2013-01-12         5  6246.480000  2013-01-12        11  10959.593000
# 12  2013-01-13         5  8299.981000  2013-01-13        11  10857.623960
# 13  2013-01-14         5  5398.938000  2013-01-14        11   7789.259030
# 14  2013-01-15         5  5528.819000  2013-01-15        11   8215.977970
# 15  2013-01-16         5  6147.083980  2013-01-16        11   7540.355000
# 16  2013-01-17         5  5109.820000  2013-01-17        11   7395.201000
# 17  2013-01-18         5  5043.555000  2013-01-18        11   7918.020000
# 18  2013-01-19         5  6228.933000  2013-01-19        11  11044.523000
# 19  2013-01-20         5  8204.085000  2013-01-20        11  11211.312000
# 20  2013-01-21         5  5511.559999  2013-01-21        11   9088.764040
# 21  2013-01-22         5  5426.481000  2013-01-22        11   7967.939000
# 22  2013-01-23         5  5624.662000  2013-01-23        11   7246.130000
# 23  2013-01-24         5  5053.194000  2013-01-24        11   7802.938000
# 24  2013-01-25         5  5591.837000  2013-01-25        11   7977.591980
# 25  2013-01-26         5  6232.117000  2013-01-26        11  10446.452000
# 26  2013-01-27         5  6562.350000  2013-01-27        11  10590.136000
# 27  2013-01-28         5  5595.128020  2013-01-28        11   8419.120000
# 28  2013-01-29         5  4720.338000  2013-01-29        11   6970.078000
# 29  2013-01-30         5  5071.153000  2013-01-30        11   7744.136020
# 30  2013-01-31         5  5230.479000  2013-01-31        11   8367.902000

# %%
# temp1 = sales1.groupby(['Date', 'Store_ID'], as_index = False)['Qty'].sum()
# temp2 = sales2.groupby(['Date', 'Store_ID'], as_index = False)['Qty'].sum()
# temp5 = sales5.groupby(['Date', 'Store_ID'], as_index = False)['Qty'].sum()
# temp11 = sales11.groupby(['Date', 'Store_ID'], as_index = False)['Qty'].sum()

# %%
# temp1.columns = ['Date', 'Store_ID', 'Qty1']
# temp2.columns = ['Date', 'Store_ID', 'Qty2']
# temp5.columns = ['Date', 'Store_ID', 'Qty5']
# temp11.columns = ['Date', 'Store_ID', 'Qty11']

# temp100 = pd.concat([temp1, temp2, temp5, temp11], axis = 1)
# temp100

# %% [markdown]
# ## **3.결합 ① : 조인 join(merge)**

# %% [markdown]
# * 판다스에서 join은 굉장히 간단합니다.
# * 자동으로 key를 잡아줍니다
# * default로 inner join을 합니다.

# %%
df1 = pd.DataFrame({'A':[1,2], 'B':[15,30], 'C':[20, 25]})
df2 = pd.DataFrame({'A':[2,3], 'D':[20, 35]})

display(df1)
display(df2)
# Out:
#    A   B   C
# 0  1  15  20
# 1  2  30  25
#    A   D
# 0  2  20
# 1  3  35

# %% [markdown]
# ### **(1) inner merge**

# %%
pd.merge(df1, df2, how = 'inner', on = 'A')
# Out:
#    A   B   C   D
# 0  2  30  25  20

# %%
pd.merge(df1, df2, how = 'inner')
# Out:
#    A   B   C   D
# 0  2  30  25  20

# %%
pd.merge(df1, df2)
# Out:
#    A   B   C   D
# 0  2  30  25  20

# %% [markdown]
# ### **(2) left merge**

# %%
pd.merge(df1, df2, how = 'left')
# Out:
#    A   B   C     D
# 0  1  15  20   NaN
# 1  2  30  25  20.0

# %% [markdown]
# ### **(3) right merge**

# %%
pd.merge(df1, df2, how = 'right')
# Out:
#    A     B     C   D
# 0  2  30.0  25.0  20
# 1  3   NaN   NaN  35

# %% [markdown]
# Merge를 여러 번 하는 방법
#
# https://stackoverflow.com/questions/44327999/how-to-merge-multiple-dataframes

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# [문1] 일별, 매장별 판매량 합계를 구해 봅시다.
# groupby, pd.merge 을 이용하여 다음과 같은 결과를 얻도록 코드를 작성해봅시다.
#
# * 힌트
#     * 1) sales1, 2, 5,11 로 부터 각각 일별 판매량 합계 집계하기
#         * 집계시 .agg() 를 이용하여 열이름 변경하거나, 집계후 열이름 변경하기
#     * 2) pd.merge 으로 결합하기

# %%
sales1.head()
# Out:
#    Order_ID        Date  Store_ID  Qty  Product_ID
# 0         3  2013-01-01         1  0.0           3
# 1         5  2013-01-01         1  0.0           5
# 2         7  2013-01-01         1  0.0           7
# 3         8  2013-01-01         1  0.0           8
# 4        10  2013-01-01         1  0.0          10

# %%
s1 = sales1.groupby(['Date', 'Store_ID'], as_index=False)['Qty'].sum()[['Date', 'Qty']].rename({'Qty': 'Qty_1'}, axis=1)
s2 = sales2.groupby(['Date', 'Store_ID'], as_index=False)['Qty'].sum()[['Date', 'Qty']].rename({'Qty': 'Qty_2'}, axis=1)
s5 = sales5.groupby(['Date', 'Store_ID'], as_index=False)['Qty'].sum()[['Date', 'Qty']].rename({'Qty': 'Qty_5'}, axis=1)
s11 = sales11.groupby(['Date', 'Store_ID'], as_index=False)['Qty'].sum()[['Date', 'Qty']].rename({'Qty': 'Qty_11'}, axis=1)

x1 = pd.merge(s1, s2, how='left', on='Date')
x2 = pd.merge(x1, s5, how='left', on='Date')

total = pd.merge(x2, s11, how='left', on='Date')
total.head(5)
# Out:
#          Date        Qty_1        Qty_2       Qty_5        Qty_11
# 0  2013-01-01     0.000000     0.000000     0.00000      0.000000
# 1  2013-01-02  6760.782000  9221.338001  9404.22902  16593.312000
# 2  2013-01-03  5348.384001  6830.089000  6932.68500  11032.676040
# 3  2013-01-04  5390.445001  6742.984000  6567.93800  10962.687002
# 4  2013-01-05  5787.839000  8583.055000  7276.80000  13315.896000

# %%
s1 = sales1.groupby(['Date', 'Store_ID'], as_index=False)['Qty'].sum().rename({'Store_ID' : 'Store_1','Qty': f'Qty_1'}, axis=1)
s2 = sales2.groupby(['Date', 'Store_ID'], as_index=False)['Qty'].sum().rename({'Store_ID' : 'Store_2','Qty': f'Qty_2'}, axis=1)
s5 = sales5.groupby(['Date', 'Store_ID'], as_index=False)['Qty'].sum().rename({'Store_ID' : 'Store_5','Qty': f'Qty_5'}, axis=1)
s11 = sales11.groupby(['Date', 'Store_ID'], as_index=False)['Qty'].sum().rename({'Store_ID' : 'Store_11','Qty': f'Qty_11'}, axis=1)

x1 = pd.merge(s1, s2, how='left', on='Date')
x2 = pd.merge(x1, s5, how='left', on='Date')
total = pd.merge(x2, s11, how='left', on='Date')
total.head(5)
# Out:
#          Date  Store_1        Qty_1  Store_2        Qty_2  Store_5  \
# 0  2013-01-01        1     0.000000        2     0.000000        5
# 1  2013-01-02        1  6760.782000        2  9221.338001        5
# 2  2013-01-03        1  5348.384001        2  6830.089000        5
# 3  2013-01-04        1  5390.445001        2  6742.984000        5
# 4  2013-01-05        1  5787.839000        2  8583.055000        5
#
#         Qty_5  Store_11        Qty_11
# 0     0.00000        11      0.000000
# 1  9404.22902        11  16593.312000
# 2  6932.68500        11  11032.676040
# 3  6567.93800        11  10962.687002
# 4  7276.80000        11  13315.896000

# %% [markdown]
# [문2] 매장1에 대해서, 일별, 카테고리별 판매량 합계를 구해 봅시다.

# %%
sales.head()
# Out:
#    Order_ID        Date  Store_ID  Qty  Product_ID
# 0         3  2013-01-01         1  0.0           3
# 1         5  2013-01-01         1  0.0           5
# 2         7  2013-01-01         1  0.0           7
# 3         8  2013-01-01         1  0.0           8
# 4        10  2013-01-01         1  0.0          10

# %%
products.sort_values('Product_ID')
# Out:
#     Product_ID Product_Code            SubCategory         Category  LeadTime  \
# 13           3        DB001               Beverage            Drink         2
# 10           5        FB001                 BAKERY             Food         2
# 12           7        HC001               Cleaning  Household Goods         2
# 11           8        FM001                   Milk             Food         2
# 8           10        GE001                   EGGS          Grocery         2
# 7           11        FF001                 Frozen             Food         2
# 14          12        GA001  Agricultural products          Grocery         3
# 3           15        HK002                Kitchen  Household Goods         2
# 2           16        HK001                Kitchen  Household Goods         2
# 0           20        HG001        Gardening Tools  Household Goods         2
# 5           22        DA001                Alcohol            Drink         2
# 9           24        GM001                  Meats          Grocery         3
# 1           27        HH001        Home Appliances  Household Goods         2
# 6           29        FP001               Prepared             Food         2
# 4           32        GS001                Seafood          Grocery         3
#
#     Price
# 13      8
# 10      6
# 12     15
# 11      4
# 8       5
# 7      29
# 14      6
# 3      41
# 2      23
# 0      50
# 5      12
# 9      17
# 1     150
# 6      18
# 4      34

# %%
t1 = pd.merge(sales1, products, how='left', on='Product_ID')
t1.groupby(['Date', 'Category'], as_index = False)['Qty'].sum()
# Out:
#            Date         Category       Qty
# 0    2013-01-01            Drink     0.000
# 1    2013-01-01             Food     0.000
# 2    2013-01-01          Grocery     0.000
# 3    2013-01-01  Household Goods     0.000
# 4    2013-01-02            Drink  1158.000
# ..          ...              ...       ...
# 119  2013-01-30  Household Goods   932.000
# 120  2013-01-31            Drink   971.000
# 121  2013-01-31             Food   751.766
# 122  2013-01-31          Grocery  1907.797
# 123  2013-01-31  Household Goods   711.000
#
# [124 rows x 3 columns]

# %% [markdown]
# - left join: 왼쪽 테이블의 모든 행 + 일치하지 않는 경우 NaN으로 표시.
# - inner join: 양쪽 테이블에 공통적으로 존재하는 행만 병합.

# %% [markdown]
# [문3] 도시별, 총판매량 합계를 구하시오.

# %%
t2 = pd.merge(sales, stores, how='left', on='Store_ID')
t2.groupby(['City'], as_index = False)['Qty'].sum()
# Out:
#              City           Qty
# 0          Albany  1.119409e+05
# 1       Annapolis  2.255278e+05
# 2       Asheville  6.644511e+04
# 3         Atlanta  3.845901e+05
# 4     Bloomington  1.315413e+05
# 5          Boston  1.138053e+05
# 6       Charlotte  1.454050e+05
# 7        Columbus  1.872153e+05
# 8      Harrisburg  1.421269e+05
# 9    Indianapolis  1.488044e+05
# 10             LA  1.009753e+05
# 11    Minneapolis  2.852598e+05
# 12      Nashville  1.182960e+05
# 13  Oklahoma City  3.102069e+05
# 14        Olympia  1.205583e+05
# 15        Phoenix  4.475075e+05
# 16        Raleigh  1.095650e+06
# 17       Richmond  2.188491e+05
# 18     Sacramento  0.000000e+00
# 19     Saint Paul  4.989027e+06
# 20     Wilmington  0.000000e+00

# %% [markdown]
# ### **(4) pivot**
# * pivot : 결합은 아니지만, 집계 후 데이터프레임 구조를 변형해서 조회하는데 종종 사용 됩니다.
#
# * 단계
#     * 1) groupby
#     * 2) pivot

# %%
# 1) 매장1의 일별 카테고리별 판매량을 집계

temp = pd.merge(sales1, products)
temp2 = temp.groupby(['Date', 'Category'], as_index = False)['Qty'].sum()
temp2
# Out:
#            Date         Category       Qty
# 0    2013-01-01            Drink     0.000
# 1    2013-01-01             Food     0.000
# 2    2013-01-01          Grocery     0.000
# 3    2013-01-01  Household Goods     0.000
# 4    2013-01-02            Drink  1158.000
# ..          ...              ...       ...
# 119  2013-01-30  Household Goods   932.000
# 120  2013-01-31            Drink   971.000
# 121  2013-01-31             Food   751.766
# 122  2013-01-31          Grocery  1907.797
# 123  2013-01-31  Household Goods   711.000
#
# [124 rows x 3 columns]

# %%
# 2) pivot
temp3 = temp2.pivot(index='Category',columns= 'Date' ,values='Qty')
temp3
# Out:
# Date             2013-01-01  2013-01-02   2013-01-03   2013-01-04  2013-01-05  \
# Category
# Drink                   0.0    1158.000   985.000000  1055.000000    1319.000
# Food                    0.0    1227.652   913.699000   790.366000     901.057
# Grocery                 0.0    3305.130  2613.685001  2711.079001    2746.782
# Household Goods         0.0    1070.000   836.000000   834.000000     821.000
#
# Date             2013-01-06  2013-01-07  2013-01-08  2013-01-09  2013-01-10  \
# Category
# Drink               407.000    1267.000    1115.000  1290.00000     914.000
# Food                416.912     852.676     829.851   967.58200     775.515
# Grocery             926.282    2689.720    2356.277  3023.57298    1933.235
# Household Goods     257.000     830.000     830.000   917.00000     687.000
#
# Date             ...  2013-01-22  2013-01-23  2013-01-24  2013-01-25  \
# Category         ...
# Drink            ...    1114.000    1152.000     924.000    1213.000
# Food             ...     780.201    1025.047     791.388     836.856
# Grocery          ...    2242.216    2824.296    2221.805    2393.208
# Household Goods  ...     786.000     769.000     622.000     701.000
#
# Date             2013-01-26  2013-01-27  2013-01-28  2013-01-29  2013-01-30  \
# Category
# Drink              1132.000     417.000     830.000     999.000    1140.000
# Food                880.019     416.783     821.064     668.154     900.092
# Grocery            2257.907    1162.207    2208.364    2001.047    2662.485
# Household Goods     551.000     247.000     625.000     617.000     932.000
#
# Date             2013-01-31
# Category
# Drink               971.000
# Food                751.766
# Grocery            1907.797
# Household Goods     711.000
#
# [4 rows x 31 columns]

# %%
# sns.heatmap으로 시각화 할 수도 있습니다!

plt.figure(figsize = (20, 6))
sns.heatmap(temp3)
plt.show()

# %% [markdown]
# ## **4.복습문제**

# %%
# 라이브러리 불러오기
import pandas as pd

# %%
sales = pd.read_csv("https://raw.githubusercontent.com/DA4BAM/dataset/master/ts_sales_simple.csv")
products = pd.read_csv("https://raw.githubusercontent.com/DA4BAM/dataset/master/ts_product_master.csv")
stores = pd.read_csv("https://raw.githubusercontent.com/DA4BAM/dataset/master/ts_store_master.csv")

# %% [markdown]
# 1) sales에 금액(Amt) 변수를 추가하시오.
# * Amt = Qty * Price

# %%
products.head()
# Out:
#    Product_ID Product_Code      SubCategory         Category  LeadTime  Price
# 0          20        HG001  Gardening Tools  Household Goods         2     50
# 1          27        HH001  Home Appliances  Household Goods         2    150
# 2          16        HK001          Kitchen  Household Goods         2     23
# 3          15        HK002          Kitchen  Household Goods         2     41
# 4          32        GS001          Seafood          Grocery         3     34

# %%
new_sales = pd.merge(sales, products, how='left', on = 'Product_ID')
new_sales['Amt'] = new_sales['Qty'] * new_sales['Price']

new_sales
# Out:
#        Order_ID        Date  Store_ID      Qty  Product_ID Product_Code  \
# 0             3  2013-01-01         1    0.000           3        DB001
# 1             5  2013-01-01         1    0.000           5        FB001
# 2             7  2013-01-01         1    0.000           7        HC001
# 3             8  2013-01-01         1    0.000           8        FM001
# 4            10  2013-01-01         1    0.000          10        GE001
# ...         ...         ...       ...      ...         ...          ...
# 25105     55231  2013-01-31         9   47.000          22        DA001
# 25106     55233  2013-01-31         9  348.475          24        GM001
# 25107     55236  2013-01-31         9    0.000          27        HH001
# 25108     55238  2013-01-31         9   42.000          29        FP001
# 25109     55241  2013-01-31         9   24.986          32        GS001
#
#            SubCategory         Category  LeadTime  Price       Amt
# 0             Beverage            Drink         2      8     0.000
# 1               BAKERY             Food         2      6     0.000
# 2             Cleaning  Household Goods         2     15     0.000
# 3                 Milk             Food         2      4     0.000
# 4                 EGGS          Grocery         2      5     0.000
# ...                ...              ...       ...    ...       ...
# 25105          Alcohol            Drink         2     12   564.000
# 25106            Meats          Grocery         3     17  5924.075
# 25107  Home Appliances  Household Goods         2    150     0.000
# 25108         Prepared             Food         2     18   756.000
# 25109          Seafood          Grocery         3     34   849.524
#
# [25110 rows x 11 columns]

# %% [markdown]
# 2) City별 매출액

# %%
sales_store = pd.merge(new_sales, stores, how = 'left', on = 'Store_ID')
sales_store.groupby(['City'], as_index=False)['Amt'].sum()
# Out:
#              City           Amt
# 0          Albany  9.618918e+05
# 1       Annapolis  1.926923e+06
# 2       Asheville  5.699986e+05
# 3         Atlanta  3.374833e+06
# 4     Bloomington  1.154652e+06
# 5          Boston  9.879414e+05
# 6       Charlotte  1.229219e+06
# 7        Columbus  1.650586e+06
# 8      Harrisburg  1.345873e+06
# 9    Indianapolis  1.256235e+06
# 10             LA  8.744844e+05
# 11    Minneapolis  2.545655e+06
# 12      Nashville  1.019337e+06
# 13  Oklahoma City  2.745415e+06
# 14        Olympia  1.053570e+06
# 15        Phoenix  4.192750e+06
# 16        Raleigh  9.539228e+06
# 17       Richmond  1.866015e+06
# 18     Sacramento  0.000000e+00
# 19     Saint Paul  4.479337e+07
# 20     Wilmington  0.000000e+00

# %% [markdown]
# 3) City별 카테고리별 매출액

# %%
sales_store.groupby(['City', 'Category'], as_index = False)['Amt'].sum()
# Out:
#           City         Category           Amt
# 0       Albany            Drink  2.367080e+05
# 1       Albany             Food  6.998561e+04
# 2       Albany          Grocery  3.676481e+05
# 3       Albany  Household Goods  2.875500e+05
# 4    Annapolis            Drink  3.507200e+05
# ..         ...              ...           ...
# 79  Saint Paul  Household Goods  1.081224e+07
# 80  Wilmington            Drink  0.000000e+00
# 81  Wilmington             Food  0.000000e+00
# 82  Wilmington          Grocery  0.000000e+00
# 83  Wilmington  Household Goods  0.000000e+00
#
# [84 rows x 3 columns]

# %% [markdown]
# 4) 매출액이 가장 높은 주(state) top 3

# %%
# sales_store = sales_store.groupby(['State'], as_index = False)['Amt'].sum()
# sales_store.sort_values('Amt', ascending = False).head(3)

sales_store.groupby(['State'], as_index=False)['Amt'].sum().sort_values(['Amt'], ascending=False).head(3)
# Out:
#             State           Amt
# 6       Minnesota  4.733903e+07
# 8  North Carolina  1.133845e+07
# 0         Arizona  4.192750e+06

# %%
# 또는
sales_store.groupby(['State'], as_index=False)['Amt'].sum().sort_values(['Amt'], ascending=False).head(3)
# Out:
#             State           Amt
# 6       Minnesota  4.733903e+07
# 8  North Carolina  1.133845e+07
# 0         Arizona  4.192750e+06

# %% [markdown]
# 추가 문제

# %% [markdown]
# * 2013년 1월 세째 주 각 도시별 subCategory별 금액 비교
#     1. 2013년 1월 세째 주
#         * sales['Date']를 날짜 타입으로 변환
#         * week 추가
#         * sales에서 week가 3인 데이터 뽑기
#     2. 각 도시별 subCategory별
#         * 1의 결과에서...
#         * stores와 inner merge
#         * products와 inner merge
#     3. 도시별 subCategory별 금액
#         * Qty * Price로 Amt 추가
#         * groupby
#     4. 좀더 보기 좋게! pivot + heatmap
#         * pivot
#         * heatmap

# %%
# 1. 날짜 변환 및 주 추가
sales_store['Date'] = pd.to_datetime(sales_store['Date'])
# sales_store['Year'] = sales_store['Date'].dt.year
# sales_store['Month'] = sales_store['Date'].dt.month
sales_store['Week'] = sales_store['Date'].dt.isocalendar().week
sales_store.head()
# Out:
#    Order_ID       Date  Store_ID  Qty  Product_ID Product_Code SubCategory  \
# 0         3 2013-01-01         1  0.0           3        DB001    Beverage
# 1         5 2013-01-01         1  0.0           5        FB001      BAKERY
# 2         7 2013-01-01         1  0.0           7        HC001    Cleaning
# 3         8 2013-01-01         1  0.0           8        FM001        Milk
# 4        10 2013-01-01         1  0.0          10        GE001        EGGS
#
#           Category  LeadTime  Price  Amt        City      State  Store_Type  \
# 0            Drink         2      8  0.0  Saint Paul  Minnesota           4
# 1             Food         2      6  0.0  Saint Paul  Minnesota           4
# 2  Household Goods         2     15  0.0  Saint Paul  Minnesota           4
# 3             Food         2      4  0.0  Saint Paul  Minnesota           4
# 4          Grocery         2      5  0.0  Saint Paul  Minnesota           4
#
#    Week
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %%
# 2013년 1월 셋째 주 데이터 필터링
week3_sales = sales_store[(sales_store['Date'].dt.year == 2013) &
                          (sales_store['Date'].dt.month == 1) &
                          (sales_store['Week'] == 3)]

# 데이터 확인
print(week3_sales.head())
# Out:
#        Order_ID       Date  Store_ID       Qty  Product_ID Product_Code  \
# 10530     23169 2013-01-14         1  1178.000           3        DB001
# 10531     23171 2013-01-14         1   281.286           5        FB001
# 10532     23173 2013-01-14         1   692.000           7        HC001
# 10533     23174 2013-01-14         1   411.000           8        FM001
# 10534     23176 2013-01-14         1   143.000          10        GE001
#
#       SubCategory         Category  LeadTime  Price        Amt        City  \
# 10530    Beverage            Drink         2      8   9424.000  Saint Paul
# 10531      BAKERY             Food         2      6   1687.716  Saint Paul
# 10532    Cleaning  Household Goods         2     15  10380.000  Saint Paul
# 10533        Milk             Food         2      4   1644.000  Saint Paul
# 10534        EGGS          Grocery         2      5    715.000  Saint Paul
#
#            State  Store_Type  Week
# 10530  Minnesota           4     3
# 10531  Minnesota           4     3
# 10532  Minnesota           4     3
# 10533  Minnesota           4     3
# 10534  Minnesota           4     3

# %%
# 도시별 subCategory별 금액 집계
city_subCategory_amt = week3_sales.groupby(['City', 'SubCategory'], as_index=False)['Amt'].sum()

# 데이터 확인
print(city_subCategory_amt.head())
# Out:
#      City            SubCategory      Amt
# 0  Albany  Agricultural products  67224.0
# 1  Albany                Alcohol   6336.0
# 2  Albany                 BAKERY   7530.0
# 3  Albany               Beverage  45360.0
# 4  Albany               Cleaning  61365.0

# %%
# 피벗 테이블 생성
pivot_table = city_subCategory_amt.pivot(index='City', columns='SubCategory', values='Amt')

# 히트맵 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(pivot_table, annot=True, fmt=".1f", cmap="YlGnBu", linewidths=.5)
plt.title('2013년 1월 셋째 주 각 도시별 SubCategory별 금액 비교')
plt.xlabel('SubCategory')
plt.ylabel('City')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49483 (\N{HANGUL SYLLABLE SES}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51704 (\N{HANGUL SYLLABLE JJAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50529 (\N{HANGUL SYLLABLE AEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
