# %% [markdown]
# # pandas 기초2 : 데이터프레임 조회 및 집계

# %% [markdown]
# ## 3.데이터프레임 조회
#
# - 보고자 하는 데이터를 즉시 조회할 수 있도록 반복 학습과 실습을 통해 익숙해져야 합니다.
# - 데이터프레임을 대상으로 조회하는 방법은 다양합니다.
# - 그 중 한 가지 방법을 선택해 일관되게 사용하기를 권고합니다.

# %%
# 라이브러리 불러오기
import pandas as pd

# %% [markdown]
# ### (1) 데이터 읽어오기

# %% [markdown]
# * Attrition 데이터 불러오기

# %% [markdown]
# **[Attrition 데이터 셋 정보]**
#
# |	구분	|	변수 명	|	내용	|	type	|	비고	|
# |----|----|----|----|----|
# |	**Target**	|	**Attrition**	|	이직여부, Yes , No	|	범주	| 1- 이직, 0- 잔류		|
# |	feature	|	Age	|	나이	|	숫자	|		|
# |	feature	|	DistanceFromHome	|	집-직장 거리	|	숫자	|	마일	|
# |	feature	|	EmployNumber	|	사번	|	숫자	| 	|
# |	feature	|	Gender	|	성별	|	범주	| Male, Female		|
# |	feature	|	JobSatisfaction	|	직무 만족도	|	범주	|	1 Low, 2 Medium, 3 High, 4 Very High	|
# |	feature	|	MaritalStatus	|	결혼상태	|	범주	| Single, Married, Divorced		|
# |	feature	|	MonthlyIncome	|	월급	|	숫자	| 달러	|
# |	feature	|	OverTime	|	야근여부	|	범주	|	Yes, No	|
# |	feature	|	PercentSalaryHike	|	전년대비 급여인상율	|	숫자	|	%	|
# |	feature	|	TotalWorkingYears	|	총 경력 연수	|	숫자	|		|

# %%
# 데이터 읽어오기
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/Attrition_simple2.CSV'
data = pd.read_csv(path)

# 상위 5개 확인
data.head(5)
# Out:
#    Attrition  Age  DistanceFromHome  EmployeeNumber  Gender  JobSatisfaction  \
# 0          0   33                 7             817    Male                3
# 1          0   35                18            1412    Male                4
# 2          0   42                 6            1911    Male                1
# 3          0   46                 2            1204  Female                1
# 4          1   22                 4             593    Male                3
#
#   MaritalStatus  MonthlyIncome OverTime  PercentSalaryHike  TotalWorkingYears
# 0       Married          11691       No                 11                 14
# 1        Single           9362       No                 11                 10
# 2       Married          13348       No                 13                 18
# 3       Married          17048       No                 23                 28
# 4        Single           3894       No                 16                  4

# %%
# 확인
data.head()
# Out:
#    Attrition  Age  DistanceFromHome  EmployeeNumber  Gender  JobSatisfaction  \
# 0          0   33                 7             817    Male                3
# 1          0   35                18            1412    Male                4
# 2          0   42                 6            1911    Male                1
# 3          0   46                 2            1204  Female                1
# 4          1   22                 4             593    Male                3
#
#   MaritalStatus  MonthlyIncome OverTime  PercentSalaryHike  TotalWorkingYears
# 0       Married          11691       No                 11                 14
# 1        Single           9362       No                 11                 10
# 2       Married          13348       No                 13                 18
# 3       Married          17048       No                 23                 28
# 4        Single           3894       No                 16                  4

# %% [markdown]
# * 시리즈(Series)와 데이터프레임(DataFrame)
#     * 데이터프레임 : 2차원 구조
#     * 시리즈 : 1차원 구조
#         * 데이터프레임에서 열 하나를 띄어 내면 시리즈!

# %% [markdown]
# <img src='https://github.com/DA4BAM/image/blob/main/%EC%8B%9C%EB%A6%AC%EC%A6%88,%20%EB%8D%B0%EC%9D%B4%ED%84%B0%ED%94%84%EB%A0%88%EC%9E%84.png?raw=true' width=500 align="left"/>

# %% [markdown]
# ### (2) 특정 열 조회
#
# - **df.loc[ : , [열 이름1, 열 이름2,...]]** 형태로 조회할 열 이름을 리스트로 지정합니다.
# - 열 부분은 생략할 수 있었지만, **행 부분을 생략할 수는 없습니다.**
# - 하지만 **df[[열 이름1, 열 이름2,...]]** 형태로 인덱서를 생략함이 일반적입니다.
# - 조회할 열이 하나면 리스트 형태가 아니어도 됩니다.

# %%
# Attrition 열 조회 : 시리즈로 조회
data['Attrition']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 1191    0
# 1192    0
# 1193    0
# 1194    0
# 1195    0
# Name: Attrition, Length: 1196, dtype: int64

# %%
# Attrition 열 조회2 : 시리즈로 조회
data.Attrition
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 1191    0
# 1192    0
# 1193    0
# 1194    0
# 1195    0
# Name: Attrition, Length: 1196, dtype: int64

# %%
# Attrition, Age 열 조회 : 데이터프레임으로 조회
# 대괄호 안에 또 대괄호로 읽지 마시고, 대괄호 안에 리스트!!!
data[['Attrition', 'Age' ]]
# Out:
#       Attrition  Age
# 0             0   33
# 1             0   35
# 2             0   42
# 3             0   46
# 4             1   22
# ...         ...  ...
# 1191          0   32
# 1192          0   27
# 1193          0   29
# 1194          0   29
# 1195          0   43
#
# [1196 rows x 2 columns]

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# [문1] data 데이터프레임에 대해 아래 요구사항에 맞는 구문을 작성하고 실행하세요.

# %%
# 상위 5개 행 조회
data.head(5)
# Out:
#    Attrition  Age  DistanceFromHome  EmployeeNumber  Gender  JobSatisfaction  \
# 0          0   33                 7             817    Male                3
# 1          0   35                18            1412    Male                4
# 2          0   42                 6            1911    Male                1
# 3          0   46                 2            1204  Female                1
# 4          1   22                 4             593    Male                3
#
#   MaritalStatus  MonthlyIncome OverTime  PercentSalaryHike  TotalWorkingYears
# 0       Married          11691       No                 11                 14
# 1        Single           9362       No                 11                 10
# 2       Married          13348       No                 13                 18
# 3       Married          17048       No                 23                 28
# 4        Single           3894       No                 16                  4

# %%
# PercentSalaryHike 열만 조회
data['PercentSalaryHike']
# Out:
# 0       11
# 1       11
# 2       13
# 3       23
# 4       16
#         ..
# 1191    12
# 1192    11
# 1193    18
# 1194    14
# 1195    22
# Name: PercentSalaryHike, Length: 1196, dtype: int64

# %%
#  Age, DistanceFromHome, Gender열만 조회
data[['Age', 'DistanceFromHome', 'Gender']]
# Out:
#       Age  DistanceFromHome  Gender
# 0      33                 7    Male
# 1      35                18    Male
# 2      42                 6    Male
# 3      46                 2  Female
# 4      22                 4    Male
# ...   ...               ...     ...
# 1191   32                 5  Female
# 1192   27                19    Male
# 1193   29                 9    Male
# 1194   29                 2    Male
# 1195   43                16  Female
#
# [1196 rows x 3 columns]

# %%
# Age, DistanceFromHome, Gender열만 DistanceFromHome 열 기준으로 내림차순 정렬해서 조회
data[['Age', 'DistanceFromHome', 'Gender']].sort_values(['DistanceFromHome'], axis=0, ascending=False)
# Out:
#       Age  DistanceFromHome  Gender
# 198    50                29    Male
# 245    32                29  Female
# 614    24                29    Male
# 810    48                29  Female
# 312    57                29    Male
# ...   ...               ...     ...
# 138    34                 1  Female
# 410    32                 1  Female
# 1050   28                 1  Female
# 778    33                 1    Male
# 124    35                 1  Female
#
# [1196 rows x 3 columns]

# %% [markdown]
# ### (3) 조건으로 조회 : **.loc**
#
# - **df.loc[조건]** 형태로 조건을 지정해 조건에 만족하는 데이터만 조회할 수 있습니다.
# - 우선 조건이 제대로 판단이 되는지 확인한 후 그 **조건을 대 괄호 안에** 넣으면 됩니다.

# %% [markdown]
# #### 1) 단일 조건 조회

# %%
# 조건절(조건문)의 결과는 True, False
data['DistanceFromHome'] > 10
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 1191    False
# 1192     True
# 1193    False
# 1194    False
# 1195     True
# Name: DistanceFromHome, Length: 1196, dtype: bool

# %%
# DistanceFromHome 열 값이 10 보다 큰 행 조회
data.loc[data['DistanceFromHome'] > 10]
# Out:
#       Attrition  Age  DistanceFromHome  EmployeeNumber  Gender  \
# 1             0   35                18            1412    Male
# 5             0   24                21            1551    Male
# 7             0   30                20            1084    Male
# 11            1   33                15             582    Male
# 15            0   34                23              60    Male
# ...         ...  ...               ...             ...     ...
# 1181          0   35                28            1596    Male
# 1186          1   26                20            1818  Female
# 1188          0   29                19            1497    Male
# 1192          0   27                19            1619    Male
# 1195          0   43                16             327  Female
#
#       JobSatisfaction MaritalStatus  MonthlyIncome OverTime  \
# 1                   4        Single           9362       No
# 5                   1      Divorced           2296       No
# 7                   1       Married           9957       No
# 11                  3       Married          13610      Yes
# 15                  3        Single           4568       No
# ...               ...           ...            ...      ...
# 1181                3       Married           3407       No
# 1186                2       Married           2148      Yes
# 1188                3      Divorced           8620       No
# 1192                1      Divorced           4066       No
# 1195                4       Married          16064      Yes
#
#       PercentSalaryHike  TotalWorkingYears
# 1                    11                 10
# 5                    14                  2
# 7                    15                  7
# 11                   12                 15
# 15                   20                 10
# ...                 ...                ...
# 1181                 17                 10
# 1186                 11                  6
# 1188                 14                 10
# 1192                 11                  7
# 1195                 22                 22
#
# [363 rows x 11 columns]

# %% [markdown]
# #### 2) 여러 조건 조회
#
# - [ ]안에 조건을 여러개 연결할 때 **and와 or 대신에 &와 |**를 사용해야 합니다.
# - 그리고 각 조건들은 **(조건1) & (조건2)** 형태로 **괄호**로 묶어야 합니다.

# %%
# and로 여러 조건 연결
data.loc[(data['DistanceFromHome'] > 10) & (data['JobSatisfaction'] == 4)]
# Out:
#       Attrition  Age  DistanceFromHome  EmployeeNumber  Gender  \
# 1             0   35                18            1412    Male
# 50            0   29                15             346    Male
# 51            0   45                28            1546    Male
# 64            0   32                15            1955  Female
# 82            1   35                12            1667    Male
# ...         ...  ...               ...             ...     ...
# 1104          0   34                19            1701  Female
# 1126          0   35                11            1137    Male
# 1141          1   49                11             840  Female
# 1148          0   36                18            1133    Male
# 1195          0   43                16             327  Female
#
#       JobSatisfaction MaritalStatus  MonthlyIncome OverTime  \
# 1                   4        Single           9362       No
# 50                  4        Single           2340       No
# 51                  4       Married           2132       No
# 64                  4      Divorced           6667       No
# 82                  4        Single           4581      Yes
# ...               ...           ...            ...      ...
# 1104                4       Married           2929       No
# 1126                4      Divorced           4968       No
# 1141                4       Married           7654       No
# 1148                4        Single           7779       No
# 1195                4       Married          16064      Yes
#
#       PercentSalaryHike  TotalWorkingYears
# 1                    11                 10
# 50                   19                  6
# 51                   20                  8
# 64                   18                  9
# 82                   24                 13
# ...                 ...                ...
# 1104                 12                 10
# 1126                 11                  5
# 1141                 18                  9
# 1148                 20                 18
# 1195                 22                 22
#
# [107 rows x 11 columns]

# %%
# or 조건 : |
data.loc[(data['DistanceFromHome'] > 10) | (data['JobSatisfaction'] == 4)]
# Out:
#       Attrition  Age  DistanceFromHome  EmployeeNumber  Gender  \
# 1             0   35                18            1412    Male
# 5             0   24                21            1551    Male
# 7             0   30                20            1084    Male
# 8             0   26                 6             686  Female
# 11            1   33                15             582    Male
# ...         ...  ...               ...             ...     ...
# 1186          1   26                20            1818  Female
# 1188          0   29                19            1497    Male
# 1190          0   27                 5             844    Male
# 1192          0   27                19            1619    Male
# 1195          0   43                16             327  Female
#
#       JobSatisfaction MaritalStatus  MonthlyIncome OverTime  \
# 1                   4        Single           9362       No
# 5                   1      Divorced           2296       No
# 7                   1       Married           9957       No
# 8                   4       Married           2659      Yes
# 11                  3       Married          13610      Yes
# ...               ...           ...            ...      ...
# 1186                2       Married           2148      Yes
# 1188                3      Divorced           8620       No
# 1190                4      Divorced          12808      Yes
# 1192                1      Divorced           4066       No
# 1195                4       Married          16064      Yes
#
#       PercentSalaryHike  TotalWorkingYears
# 1                    11                 10
# 5                    14                  2
# 7                    15                  7
# 8                    13                  3
# 11                   12                 15
# ...                 ...                ...
# 1186                 11                  6
# 1188                 14                 10
# 1190                 16                  9
# 1192                 11                  7
# 1195                 22                 22
#
# [629 rows x 11 columns]

# %% [markdown]
# #### 3) isin(), between()
#
# - **isin([값1, 값2,..., 값n])**: 값1 또는 값2 또는...값n인 데이터만 조회합니다.
# - 주의 isin(**리스트**) 값들을 리스트 형태로 입력해야 합니다.

# %%
# 값 나열
data.loc[data['JobSatisfaction'].isin([1,4])]
# Out:
#       Attrition  Age  DistanceFromHome  EmployeeNumber  Gender  \
# 1             0   35                18            1412    Male
# 2             0   42                 6            1911    Male
# 3             0   46                 2            1204  Female
# 5             0   24                21            1551    Male
# 7             0   30                20            1084    Male
# ...         ...  ...               ...             ...     ...
# 1184          0   33                 5            1395    Male
# 1185          0   24                10            1746    Male
# 1190          0   27                 5             844    Male
# 1192          0   27                19            1619    Male
# 1195          0   43                16             327  Female
#
#       JobSatisfaction MaritalStatus  MonthlyIncome OverTime  \
# 1                   4        Single           9362       No
# 2                   1       Married          13348       No
# 3                   1       Married          17048       No
# 5                   1      Divorced           2296       No
# 7                   1       Married           9957       No
# ...               ...           ...            ...      ...
# 1184                4       Married           9998       No
# 1185                4       Married           2145       No
# 1190                4      Divorced          12808      Yes
# 1192                1      Divorced           4066       No
# 1195                4       Married          16064      Yes
#
#       PercentSalaryHike  TotalWorkingYears
# 1                    11                 10
# 2                    13                 18
# 3                    23                 28
# 5                    14                  2
# 7                    15                  7
# ...                 ...                ...
# 1184                 13                  8
# 1185                 14                  3
# 1190                 16                  9
# 1192                 11                  7
# 1195                 22                 22
#
# [616 rows x 11 columns]

# %% [markdown]
# - 위 구문은 다음과 같은 의미를 갖습니다.

# %%
# or 조건
data.loc[(data['JobSatisfaction'] == 1) | (data['JobSatisfaction'] == 4)]
# Out:
#       Attrition  Age  DistanceFromHome  EmployeeNumber  Gender  \
# 1             0   35                18            1412    Male
# 2             0   42                 6            1911    Male
# 3             0   46                 2            1204  Female
# 5             0   24                21            1551    Male
# 7             0   30                20            1084    Male
# ...         ...  ...               ...             ...     ...
# 1184          0   33                 5            1395    Male
# 1185          0   24                10            1746    Male
# 1190          0   27                 5             844    Male
# 1192          0   27                19            1619    Male
# 1195          0   43                16             327  Female
#
#       JobSatisfaction MaritalStatus  MonthlyIncome OverTime  \
# 1                   4        Single           9362       No
# 2                   1       Married          13348       No
# 3                   1       Married          17048       No
# 5                   1      Divorced           2296       No
# 7                   1       Married           9957       No
# ...               ...           ...            ...      ...
# 1184                4       Married           9998       No
# 1185                4       Married           2145       No
# 1190                4      Divorced          12808      Yes
# 1192                1      Divorced           4066       No
# 1195                4       Married          16064      Yes
#
#       PercentSalaryHike  TotalWorkingYears
# 1                    11                 10
# 2                    13                 18
# 3                    23                 28
# 5                    14                  2
# 7                    15                  7
# ...                 ...                ...
# 1184                 13                  8
# 1185                 14                  3
# 1190                 16                  9
# 1192                 11                  7
# 1195                 22                 22
#
# [616 rows x 11 columns]

# %% [markdown]
# - **between(값1, 값2)**: 값1 ~ 값2까지 범위안의 데이터만 조회합니다.
#
#     * inclusive = 'both' (기본값)
#         * 'left', 'right', 'neither'

# %%
# 범위 지정
data.loc[data['Age'].between(25, 30)]
# Out:
#       Attrition  Age  DistanceFromHome  EmployeeNumber  Gender  \
# 7             0   30                20            1084    Male
# 8             0   26                 6             686  Female
# 16            0   30                 5             197  Female
# 28            0   26                 1            1893  Female
# 32            0   30                 7            1224    Male
# ...         ...  ...               ...             ...     ...
# 1188          0   29                19            1497    Male
# 1190          0   27                 5             844    Male
# 1192          0   27                19            1619    Male
# 1193          0   29                 9            1558    Male
# 1194          0   29                 2             469    Male
#
#       JobSatisfaction MaritalStatus  MonthlyIncome OverTime  \
# 7                   1       Married           9957       No
# 8                   4       Married           2659      Yes
# 16                  1      Divorced           3204       No
# 28                  3       Married           2933      Yes
# 32                  3      Divorced           3491       No
# ...               ...           ...            ...      ...
# 1188                3      Divorced           8620       No
# 1190                4      Divorced          12808      Yes
# 1192                1      Divorced           4066       No
# 1193                3       Married           2451       No
# 1194                3       Married           4649       No
#
#       PercentSalaryHike  TotalWorkingYears
# 7                    15                  7
# 8                    13                  3
# 16                   14                  8
# 28                   13                  1
# 32                   13                 10
# ...                 ...                ...
# 1188                 14                 10
# 1190                 16                  9
# 1192                 11                  7
# 1193                 18                  5
# 1194                 14                  4
#
# [238 rows x 11 columns]

# %% [markdown]
# - 위 구문은 다음과 같은 의미를 갖습니다.

# %%
# and 조건
data.loc[(data['Age'] >= 25) & (data['Age'] <= 30)]
# Out:
#       Attrition  Age  DistanceFromHome  EmployeeNumber  Gender  \
# 7             0   30                20            1084    Male
# 8             0   26                 6             686  Female
# 16            0   30                 5             197  Female
# 28            0   26                 1            1893  Female
# 32            0   30                 7            1224    Male
# ...         ...  ...               ...             ...     ...
# 1188          0   29                19            1497    Male
# 1190          0   27                 5             844    Male
# 1192          0   27                19            1619    Male
# 1193          0   29                 9            1558    Male
# 1194          0   29                 2             469    Male
#
#       JobSatisfaction MaritalStatus  MonthlyIncome OverTime  \
# 7                   1       Married           9957       No
# 8                   4       Married           2659      Yes
# 16                  1      Divorced           3204       No
# 28                  3       Married           2933      Yes
# 32                  3      Divorced           3491       No
# ...               ...           ...            ...      ...
# 1188                3      Divorced           8620       No
# 1190                4      Divorced          12808      Yes
# 1192                1      Divorced           4066       No
# 1193                3       Married           2451       No
# 1194                3       Married           4649       No
#
#       PercentSalaryHike  TotalWorkingYears
# 7                    15                  7
# 8                    13                  3
# 16                   14                  8
# 28                   13                  1
# 32                   13                 10
# ...                 ...                ...
# 1188                 14                 10
# 1190                 16                  9
# 1192                 11                  7
# 1193                 18                  5
# 1194                 14                  4
#
# [238 rows x 11 columns]

# %% [markdown]
# #### **4) 조건을 만족하는 행의 일부 열 조회**
#
# - **df.loc[조건, ['열 이름1', '열 이름2',...]]** 형태로 조회할 열을 리스트로 지정합니다. ==> 2차원, 데이터프레임형태로 조회

# %%
# 조건에 맞는 하나의 열 조회
data.loc[data['MonthlyIncome'] >= 10000, ['Age']]
# Out:
#       Age
# 0      33
# 2      42
# 3      46
# 11     33
# 13     39
# ...   ...
# 1157   42
# 1158   54
# 1166   34
# 1190   27
# 1195   43
#
# [230 rows x 1 columns]

# %%
# 조건에 맞는 여러 열 조회
data.loc[data['MonthlyIncome'] >= 10000, ['Age', 'MaritalStatus', 'TotalWorkingYears']]
# Out:
#       Age MaritalStatus  TotalWorkingYears
# 0      33       Married                 14
# 2      42       Married                 18
# 3      46       Married                 28
# 11     33       Married                 15
# 13     39        Single                 21
# ...   ...           ...                ...
# 1157   42        Single                 24
# 1158   54       Married                 36
# 1166   34        Single                 14
# 1190   27      Divorced                  9
# 1195   43       Married                 22
#
# [230 rows x 3 columns]

# %% [markdown]
# - 나이가 50대 (50 ~ 59)이고, 월급이 10,000 보다 작은 직원 정보를 조회해 봅시다.
# - 나이, 월급, 성별, 회사에서 집까지 거리를 조회해 봅시다.

# %%
condition = (data['Age'].between(50, 60, inclusive='left')) & (data['MonthlyIncome'] < 10000)
data.loc[condition, ['Age', 'MonthlyIncome', 'Gender', 'DistanceFromHome']].head()
# Out:
#      Age  MonthlyIncome  Gender  DistanceFromHome
# 17    58           2380    Male                 2
# 48    50           3690    Male                 1
# 59    52           3212  Female                 2
# 75    53           8381  Female                 1
# 116   59           5473  Female                 1

# %% [markdown]
# ### (4) 복습문제

# %% [markdown]
# [문1] pandas 라이브러리를 pd 별칭을 주어 불러오세요.

# %%
# 라이브러리 불러오기

import pandas as pd

# %% [markdown]
# [문2] read_csv() 함수를 사용해 다음 경로의 파일을 불러와 **titanic** 데이터프레임을 만드세요.
#
# - 파일 경로: 'https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic_simple.csv'

# %% [markdown]
# **[titanic_simple 데이터 셋 정보]**
#
# - PassengerId : 승객번호
# - Survived : 생존여부(1:생존, 0:사망)
# - Pclass : 객실등급(1:1등급, 2:2등급, 3:3등급)
# - Name : 승객이름
# - Sex : 성별(male, female)
# - Age : 나이
# - Fare : 운임($)
# - Embarked : 승선지역(Southhampton, Cherbourg, Queenstown)

# %%
# 파일 읽어오기

titanic = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic_simple.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age     Fare  \
# 0                              Braund, Mr. Owen Harris    male  22.0   7.2500
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  71.2833
# 2                               Heikkinen, Miss. Laina  female  26.0   7.9250
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4                             Allen, Mr. William Henry    male  35.0   8.0500
# ..                                                 ...     ...   ...      ...
# 886                              Montvila, Rev. Juozas    male  27.0  13.0000
# 887                       Graham, Miss. Margaret Edith  female  19.0  30.0000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN  23.4500
# 889                              Behr, Mr. Karl Howell    male  26.0  30.0000
# 890                                Dooley, Mr. Patrick    male  32.0   7.7500
#
#         Embarked
# 0    Southampton
# 1      Cherbourg
# 2    Southampton
# 3    Southampton
# 4    Southampton
# ..           ...
# 886  Southampton
# 887  Southampton
# 888  Southampton
# 889    Cherbourg
# 890   Queenstown
#
# [891 rows x 8 columns]

# %% [markdown]
# [문3] Name 열만 조회하세요.

# %%
# 자료형: Series (1차원)
titanic['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
# 자료형: List (2차원)

titanic[['Name']]
# Out:
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 886                              Montvila, Rev. Juozas
# 887                       Graham, Miss. Margaret Edith
# 888           Johnston, Miss. Catherine Helen "Carrie"
# 889                              Behr, Mr. Karl Howell
# 890                                Dooley, Mr. Patrick
#
# [891 rows x 1 columns]

# %% [markdown]
# [문4] Name, Age, Sex 열만 조회하세요.

# %%
titanic[['Name', 'Age', 'Sex']]
# Out:
#                                                   Name   Age     Sex
# 0                              Braund, Mr. Owen Harris  22.0    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                               Heikkinen, Miss. Laina  26.0  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                             Allen, Mr. William Henry  35.0    male
# ..                                                 ...   ...     ...
# 886                              Montvila, Rev. Juozas  27.0    male
# 887                       Graham, Miss. Margaret Edith  19.0  female
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN  female
# 889                              Behr, Mr. Karl Howell  26.0    male
# 890                                Dooley, Mr. Patrick  32.0    male
#
# [891 rows x 3 columns]

# %% [markdown]
# [문5] Name, Age, Sex 열의 상위 10개 행만 확인하세요.

# %%
titanic[['Name', 'Age', 'Sex']].head(10)
# Out:
#                                                 Name   Age     Sex
# 0                            Braund, Mr. Owen Harris  22.0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                             Heikkinen, Miss. Laina  26.0  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                           Allen, Mr. William Henry  35.0    male
# 5                                   Moran, Mr. James   NaN    male
# 6                            McCarthy, Mr. Timothy J  54.0    male
# 7                     Palsson, Master. Gosta Leonard   2.0    male
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0  female
# 9                Nasser, Mrs. Nicholas (Adele Achem)  14.0  female

# %% [markdown]
# [문6] 나이가 70세 이상인 탑승객을 조회하시오.

# %%
# titanic['Age'] >= 70 # 이렇게 하면 Fasle, True로 나옴
# 아래와 같이 해야 70세 이상 조회 가능
titanic.loc[titanic['Age'] >= 70]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age     Fare     Embarked
# 96   male  71.0  34.6542    Cherbourg
# 116  male  70.5   7.7500   Queenstown
# 493  male  71.0  49.5042    Cherbourg
# 630  male  80.0  30.0000  Southampton
# 672  male  70.0  10.5000  Southampton
# 745  male  70.0  71.0000  Southampton
# 851  male  74.0   7.7750  Southampton

# %%
# 70세 이상인 사람 중 탑승객

titanic.loc[titanic['Age'] >= 70, 'PassengerId']
# Out:
# 96      97
# 116    117
# 493    494
# 630    631
# 672    673
# 745    746
# 851    852
# Name: PassengerId, dtype: int64

# %% [markdown]
# [문7] Fare(운임)의 평균을 Fare_mean으로 저장하고 그 값을 확인하세요.

# %%
# 평균

Fare_mean = titanic['Fare'].mean()

# 확인

Fare_mean
# Out:
# 32.204207968574636

# %% [markdown]
# [문8] 평균 운임보다 적게 내고 탑승한 승객을 조회하시오.

# %%
# titanic.loc[titanic['Fare'] < Fare_mean ] # 가독성 좋은 코드
titanic.loc[titanic['Fare'] < titanic['Fare'].mean(), 'PassengerId'] # 탑승객 조회
# Out:
# 0        1
# 2        3
# 4        5
# 5        6
# 7        8
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 680, dtype: int64

# %% [markdown]
# [문9] 승선지역(Embarked)이 'Southampton', 'Queenstown' 인 승객을 조회하시오.

# %%
# isin([ , , ])
titanic.loc[titanic['Embarked'].isin(['Southampton', 'Queenstown'])]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 890          891         0       3
#
#                                              Name     Sex   Age     Fare  \
# 0                         Braund, Mr. Owen Harris    male  22.0   7.2500
# 2                          Heikkinen, Miss. Laina  female  26.0   7.9250
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4                        Allen, Mr. William Henry    male  35.0   8.0500
# 5                                Moran, Mr. James    male   NaN   8.4583
# ..                                            ...     ...   ...      ...
# 885          Rice, Mrs. William (Margaret Norton)  female  39.0  29.1250
# 886                         Montvila, Rev. Juozas    male  27.0  13.0000
# 887                  Graham, Miss. Margaret Edith  female  19.0  30.0000
# 888      Johnston, Miss. Catherine Helen "Carrie"  female   NaN  23.4500
# 890                           Dooley, Mr. Patrick    male  32.0   7.7500
#
#         Embarked
# 0    Southampton
# 2    Southampton
# 3    Southampton
# 4    Southampton
# 5     Queenstown
# ..           ...
# 885   Queenstown
# 886  Southampton
# 887  Southampton
# 888  Southampton
# 890   Queenstown
#
# [721 rows x 8 columns]

# %%
titanic.loc[titanic['Embarked'].isin(['Southampton', 'Queenstown']), 'PassengerId']
# Out:
# 0        1
# 2        3
# 3        4
# 4        5
# 5        6
#       ...
# 885    886
# 886    887
# 887    888
# 888    889
# 890    891
# Name: PassengerId, Length: 721, dtype: int64

# %% [markdown]
# [문10] 나이(Age)가 10대(10이상, 20 미만)인 남자 청소년의 평균 운임(Fare)을 구해 봅시다.

# %%
titanic['Age'].between(10, 20, inclusive='left') & (titanic['Sex'] == 'male')
titanic.loc[(titanic['Age'].between(10, 20, inclusive='left')) & (titanic['Sex'] == 'male')]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 59            60         0       3
# 67            68         0       3
# 86            87         0       3
# 125          126         1       3
# 138          139         0       3
# 143          144         0       3
# 144          145         0       2
# 145          146         0       2
# 163          164         0       3
# 175          176         0       3
# 191          192         0       2
# 204          205         1       3
# 220          221         1       3
# 226          227         1       2
# 228          229         0       2
# 238          239         0       2
# 266          267         0       3
# 282          283         0       3
# 283          284         1       3
# 302          303         0       3
# 333          334         0       3
# 352          353         0       3
# 371          372         0       3
# 372          373         0       3
# 379          380         0       3
# 385          386         0       2
# 424          425         0       3
# 433          434         0       3
# 500          501         0       3
# 505          506         0       1
# 532          533         0       3
# 550          551         1       1
# 566          567         0       3
# 574          575         0       3
# 575          576         0       3
# 646          647         0       3
# 675          676         0       3
# 683          684         0       3
# 686          687         0       3
# 687          688         0       3
# 688          689         0       3
# 715          716         0       3
# 721          722         0       3
# 731          732         0       3
# 746          747         0       3
# 748          749         0       1
# 757          758         0       2
# 764          765         0       3
# 775          776         0       3
# 791          792         0       2
# 802          803         1       1
# 819          820         0       3
# 834          835         0       3
# 841          842         0       2
# 844          845         0       3
# 877          878         0       3
#
#                                            Name   Sex   Age      Fare  \
# 27               Fortune, Mr. Charles Alexander  male  19.0  263.0000
# 59           Goodwin, Master. William Frederick  male  11.0   46.9000
# 67                     Crease, Mr. Ernest James  male  19.0    8.1583
# 86                       Ford, Mr. William Neal  male  16.0   34.3750
# 125                Nicola-Yarred, Master. Elias  male  12.0   11.2417
# 138                         Osen, Mr. Olaf Elon  male  16.0    9.2167
# 143                         Burke, Mr. Jeremiah  male  19.0    6.7500
# 144                  Andrew, Mr. Edgardo Samuel  male  18.0   11.5000
# 145                Nicholls, Mr. Joseph Charles  male  19.0   36.7500
# 163                             Calic, Mr. Jovo  male  17.0    8.6625
# 175                      Klasen, Mr. Klas Albin  male  18.0    7.8542
# 191                       Carbines, Mr. William  male  19.0   13.0000
# 204                    Cohen, Mr. Gurshon "Gus"  male  18.0    8.0500
# 220              Sunderland, Mr. Victor Francis  male  16.0    8.0500
# 226                   Mellors, Mr. William John  male  19.0   10.5000
# 228                   Fahlstrom, Mr. Arne Jonas  male  18.0   13.0000
# 238             Pengelly, Mr. Frederick William  male  19.0   10.5000
# 266                   Panula, Mr. Ernesti Arvid  male  16.0   39.6875
# 282                   de Pelsmaeker, Mr. Alfons  male  16.0    9.5000
# 283                  Dorking, Mr. Edward Arthur  male  19.0    8.0500
# 302             Johnson, Mr. William Cahoone Jr  male  19.0    0.0000
# 333             Vander Planke, Mr. Leo Edmondus  male  16.0   18.0000
# 352                          Elias, Mr. Tannous  male  15.0    7.2292
# 371                   Wiklund, Mr. Jakob Alfred  male  18.0    6.4958
# 372                  Beavan, Mr. William Thomas  male  19.0    8.0500
# 379                 Gustafsson, Mr. Karl Gideon  male  19.0    7.7750
# 385                   Davies, Mr. Charles Henry  male  18.0   73.5000
# 424                 Rosblom, Mr. Viktor Richard  male  18.0   20.2125
# 433                  Kallio, Mr. Nikolai Erland  male  17.0    7.1250
# 500                            Calic, Mr. Petar  male  17.0    8.6625
# 505  Penasco y Castellana, Mr. Victor de Satode  male  18.0  108.9000
# 532                        Elias, Mr. Joseph Jr  male  17.0    7.2292
# 550                 Thayer, Mr. John Borland Jr  male  17.0  110.8833
# 566                        Stoytcheff, Mr. Ilia  male  19.0    7.8958
# 574                Rush, Mr. Alfred George John  male  16.0    8.0500
# 575                        Patchett, Mr. George  male  19.0   14.5000
# 646                           Cor, Mr. Liudevit  male  19.0    7.8958
# 675              Edvardsson, Mr. Gustaf Hjalmar  male  18.0    7.7750
# 683                 Goodwin, Mr. Charles Edward  male  14.0   46.9000
# 686                    Panula, Mr. Jaako Arnold  male  14.0   39.6875
# 687                           Dakic, Mr. Branko  male  19.0   10.1708
# 688             Fischer, Mr. Eberhard Thelander  male  18.0    7.7958
# 715  Soholt, Mr. Peter Andreas Lauritz Andersen  male  19.0    7.6500
# 721                   Jensen, Mr. Svend Lauritz  male  17.0    7.0542
# 731                    Hassan, Mr. Houssein G N  male  11.0   18.7875
# 746                 Abbott, Mr. Rossmore Edward  male  16.0   20.2500
# 748                   Marvin, Mr. Daniel Warner  male  19.0   53.1000
# 757                    Bailey, Mr. Percy Andrew  male  18.0   11.5000
# 764                      Eklund, Mr. Hans Linus  male  16.0    7.7750
# 775     Myhrman, Mr. Pehr Fabian Oliver Malkolm  male  18.0    7.7500
# 791                         Gaskell, Mr. Alfred  male  16.0   26.0000
# 802         Carter, Master. William Thornton II  male  11.0  120.0000
# 819                Skoog, Master. Karl Thorsten  male  10.0   27.9000
# 834                      Allum, Mr. Owen George  male  18.0    8.3000
# 841                    Mudd, Mr. Thomas Charles  male  16.0   10.5000
# 844                         Culumovic, Mr. Jeso  male  17.0    8.6625
# 877                        Petroff, Mr. Nedelio  male  19.0    7.8958
#
#         Embarked
# 27   Southampton
# 59   Southampton
# 67   Southampton
# 86   Southampton
# 125    Cherbourg
# 138  Southampton
# 143   Queenstown
# 144  Southampton
# 145  Southampton
# 163  Southampton
# 175  Southampton
# 191  Southampton
# 204  Southampton
# 220  Southampton
# 226  Southampton
# 228  Southampton
# 238  Southampton
# 266  Southampton
# 282  Southampton
# 283  Southampton
# 302  Southampton
# 333  Southampton
# 352    Cherbourg
# 371  Southampton
# 372  Southampton
# 379  Southampton
# 385  Southampton
# 424  Southampton
# 433  Southampton
# 500  Southampton
# 505    Cherbourg
# 532    Cherbourg
# 550    Cherbourg
# 566  Southampton
# 574  Southampton
# 575  Southampton
# 646  Southampton
# 675  Southampton
# 683  Southampton
# 686  Southampton
# 687  Southampton
# 688  Southampton
# 715  Southampton
# 721  Southampton
# 731    Cherbourg
# 746  Southampton
# 748  Southampton
# 757  Southampton
# 764  Southampton
# 775  Southampton
# 791  Southampton
# 802  Southampton
# 819  Southampton
# 834  Southampton
# 841  Southampton
# 844  Southampton
# 877  Southampton

# %%
# loc 안에 왼쪽은 조건문, 오른쪽은 나오는 것 (그래서 Fare이 나오는 것임) -> mean()을 제외해서 나오는 건 자료형 Series

titanic.loc[(titanic['Age'].between(10, 20, inclusive='left')) & (titanic['Sex'] == 'male'), 'Fare'].mean()
# Out:
# 25.30884385964912

# %% [markdown]
# ## 4.데이터프레임 집계
#
# - 상세 데이터가 아닌 집계된 데이터에 대한 분석을 자주 요구하니 익숙해져야 할 내용입니다.
# - sum(), mean(), max(), min(), count() 메소드를 사용해 지정한 열 또는 열들을 기준으로 집계합니다.
# - 평균을 구하는 메소드가 avg()가 아닌 mean() 임을 주의하기 바랍니다.

# %%
# 라이브러리 불러오기
import pandas as pd

# %% [markdown]
# * Attrition 데이터 불러오기

# %% [markdown]
# **[Attrition 데이터 셋 정보]**
#
# |	구분	|	변수 명	|	내용	|	type	|	비고	|
# |----|----|----|----|----|
# |	**Target**	|	**Attrition**	|	이직여부, Yes , No	|	범주	| 1- 이직, 0- 잔류		|
# |	feature	|	Age	|	나이	|	숫자	|		|
# |	feature	|	DistanceFromHome	|	집-직장 거리	|	숫자	|	마일	|
# |	feature	|	EmployNumber	|	사번	|	숫자	| 	|
# |	feature	|	Gender	|	성별	|	범주	| Male, Female		|
# |	feature	|	JobSatisfaction	|	직무 만족도	|	범주	|	1 Low, 2 Medium, 3 High, 4 Very High	|
# |	feature	|	MaritalStatus	|	결혼상태	|	범주	| Single, Married, Divorced		|
# |	feature	|	MonthlyIncome	|	월급	|	숫자	| 달러	|
# |	feature	|	OverTime	|	야근여부	|	범주	|	Yes, No	|
# |	feature	|	PercentSalaryHike	|	전년대비 급여인상율	|	숫자	|	%	|
# |	feature	|	TotalWorkingYears	|	총 경력 연수	|	숫자	|		|

# %%
# 데이터 읽어오기
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/Attrition_simple2.CSV'
data = pd.read_csv(path)

# 상위 5개 확인
data.head(5)
# Out:
#    Attrition  Age  DistanceFromHome  EmployeeNumber  Gender  JobSatisfaction  \
# 0          0   33                 7             817    Male                3
# 1          0   35                18            1412    Male                4
# 2          0   42                 6            1911    Male                1
# 3          0   46                 2            1204  Female                1
# 4          1   22                 4             593    Male                3
#
#   MaritalStatus  MonthlyIncome OverTime  PercentSalaryHike  TotalWorkingYears
# 0       Married          11691       No                 11                 14
# 1        Single           9362       No                 11                 10
# 2       Married          13348       No                 13                 18
# 3       Married          17048       No                 23                 28
# 4        Single           3894       No                 16                  4

# %% [markdown]
# ### (1) 열 하나 집계
#
# - 우선 특정 열의 값 합은 다음과 같이 구할 수 있습니다.

# %%
# MonthlyIncome 합계
data['MonthlyIncome'].sum()
# Out:
# 7798045

# %%
# MonthlyIncome, TotalWorkingYears 각각의 평균
data[['MonthlyIncome', 'TotalWorkingYears']].mean()
# Out:
# MonthlyIncome        6520.104515
# TotalWorkingYears      11.330268
# dtype: float64

# %% [markdown]
# #### 1) 집계하기
#
# - 만일 day 별로 합을 구하고자 한다면 다음과 같이 합니다.
# - 아래 결과 값 네 개를 더하면 전체 합이 됩니다.
# - **as_index=True**를 설정(기본값)하면 집계 기준이 되는 열이 인덱스 열이 됩니다.
# - 집계 결과가 data 열만 가지니 **시리즈**가 됩니다.

# %%
# MaritalStatus 별 Age 평균 --> 시리즈
data.groupby('MaritalStatus', as_index=True)['Age'].mean()
# Out:
# MaritalStatus
# Divorced    37.522727
# Married     37.704380
# Single      35.460938
# Name: Age, dtype: float64

# %% [markdown]
# - [['data']].sum()과 같이 하면 열이 여럿이라는 의미여서 결과가 **데이터프레임**이 됩니다.

# %%
# MaritalStatus 별 Age 평균 --> 데이터프레임
data.groupby('MaritalStatus', as_index=True)[['Age']].mean()
# Out:
#                      Age
# MaritalStatus
# Divorced       37.522727
# Married        37.704380
# Single         35.460938

# %% [markdown]
# - **as_index=False**를 설정하면 행 번호를 기반으로 한 정수 값이 인덱스로 설정됩니다.

# %%
# MaritalStatus 별 Age 평균 --> 데이터프레임
data.groupby('MaritalStatus', as_index=False)[['Age']].mean()
# Out:
#   MaritalStatus        Age
# 0      Divorced  37.522727
# 1       Married  37.704380
# 2        Single  35.460938

# %% [markdown]
# as_index는 누굴 인덱스로 쓸 건지?
#
# - True 시에는 ('happy', as_index=True) : happy를 인덱스로 쓴다
# - False 시에는 0, 1, 2, 즉 행을 기반으로 인덱스로 한다 보통 이렇게 많이 씀
#
# 보통 True가 default 값이라 True 쓸 거면 생략하면 됨

# %% [markdown]
# #### 2) 데이터프레임으로 선언
#
# - 집계 결과를 새로운 데이터프레임으로 선언하여 사용하는 경우가 많습니다.
# - 집계된 결과를 반복해서 사용하거나, 분석 대상이 되는 경우 데이터프레임으로 선언함이 유익합니다.

# %%
data.groupby('MaritalStatus', as_index=False)[['Age']].mean()
# Out:
#   MaritalStatus        Age
# 0      Divorced  37.522727
# 1       Married  37.704380
# 2        Single  35.460938

# %% [markdown]
# ### (2) 여러 열 집계
#
# - 여러 열에 대한 집계를 같이 할 수 있습니다.
# - **[ ['feature1', 'feature2'] ].sum()** 형태와 같이 집계 대상 열을 리스트로 지정합니다.

# %%
data.groupby('MaritalStatus', as_index=False)[['Age','MonthlyIncome']].mean()
# Out:
#   MaritalStatus        Age  MonthlyIncome
# 0      Divorced  37.522727    6707.018939
# 1       Married  37.704380    6880.144161
# 2        Single  35.460938    5877.794271

# %% [markdown]
# - sum() 메소드 앞에 아무 열도 지정하지 않으면 **기준열 이외의 모든 열에 대한 집계**가 수행됩니다.
#     * 향후에는 이 기능이 제거될 수 있으므로 숫자형 변수만 집계되도록 명시적으로 지정할 필요가 있음

# %%
data.groupby('MaritalStatus', as_index=False).sum()
# Out:
#   MaritalStatus  Attrition    Age  DistanceFromHome  EmployeeNumber  \
# 0      Divorced         23   9906              2404          266305
# 1       Married         69  20662              5295          584446
# 2        Single        103  13617              3374          387862
#
#                                               Gender  JobSatisfaction  \
# 0  MaleFemaleFemaleMaleFemaleMaleMaleFemaleFemale...              716
# 1  MaleMaleFemaleMaleMaleFemaleMaleMaleMaleMaleFe...             1468
# 2  MaleMaleFemaleMaleMaleMaleFemaleMaleMaleMaleMa...             1065
#
#    MonthlyIncome                                           OverTime  \
# 0        1770653  NoYesNoYesNoNoNoYesNoNoYesNoYesNoNoNoNoNoNoYes...
# 1        3770319  NoNoNoNoNoYesYesNoYesNoYesYesNoNoYesNoNoNoNoNo...
# 2        2257073  NoNoNoNoNoNoYesNoNoNoNoNoNoYesYesNoNoNoYesYesN...
#
#    PercentSalaryHike  TotalWorkingYears
# 0               3958               3106
# 1               8431               6470
# 2               5852               3975

# %% [markdown]
# - **by=['feature1', 'feature2']** 과 같이 집계 기준 열을 여럿 설정할 수도 있습니다.

# %%
# 'MaritalStatus', 'Gender'별 나머지 열들 평균 조회
data_sum = data.groupby(['MaritalStatus', 'Gender'], as_index=False)[['Age','MonthlyIncome']].mean()

# 확인
data_sum
# Out:
#   MaritalStatus  Gender        Age  MonthlyIncome
# 0      Divorced  Female  37.010526    6626.315789
# 1      Divorced    Male  37.810651    6752.384615
# 2       Married  Female  38.774194    7301.493088
# 3       Married    Male  37.003021    6603.912387
# 4        Single  Female  35.261146    5963.445860
# 5        Single    Male  35.599119    5818.555066

# %% [markdown]
# ### (3) 여러 함수로 한꺼번에 집계 .agg
#
# * df.groupby(  )**.agg(['함수1','함수2', ...])**

# %%
data_agg = data.groupby('MaritalStatus', as_index=False)[['MonthlyIncome']].agg(['min','max','mean'])
# 확인
data_agg
# Out:
#   MaritalStatus MonthlyIncome
#                           min    max         mean
# 0      Divorced          1129  19973  6707.018939
# 1       Married          1052  19999  6880.144161
# 2        Single          1009  19926  5877.794271

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# [문1] 데이터를 불러와 데이터프레임으로 저장합니다.
#
# - 파일 경로 : https://raw.githubusercontent.com/DA4BAM/dataset/master/airquality.csv

# %% [markdown]
# **[airquality_simple 데이터 셋 정보]**
#
# - Ozone : 오존농도
# - Solar.R: 태양복사열
# - Wind: 풍속
# - Temp: 기온
# - Month: 월
# - Day: 일

# %%
# 데이터 읽어오기
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/airquality.csv'
air = pd.read_csv(path)

# 상위 5개 확인
air.head()
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day
# 0   41.0    190.0   7.4    67      5    1
# 1   36.0    118.0   8.0    72      5    2
# 2   12.0    149.0  12.6    74      5    3
# 3   18.0    313.0  11.5    62      5    4
# 4    NaN      NaN  14.3    56      5    5

# %% [markdown]
# [문2] 월별 Ozone, Wind, Temp 평균을 구해 봅시다.

# %%
air.groupby(['Month'], as_index=False)[['Ozone', 'Wind', 'Temp']].mean()
# Out:
#    Month      Ozone       Wind       Temp
# 0      5  23.615385  11.622581  65.548387
# 1      6  29.444444  10.266667  79.100000
# 2      7  59.115385   8.941935  83.903226
# 3      8  59.961538   8.793548  83.967742
# 4      9  31.448276  10.180000  76.900000

# %% [markdown]
# [문3] 월별 Ozone, Wind, Temp에 대해 최대, 최소, 평균, 표준편차 값을 구해 봅시다.

# %%
air.groupby(['Month'], as_index=False)[['Ozone', 'Wind', 'Temp']].mean() # 와 같이 각 컬럼에 대해 하나씩 구해도 되고
# Out:
#    Month      Ozone       Wind       Temp
# 0      5  23.615385  11.622581  65.548387
# 1      6  29.444444  10.266667  79.100000
# 2      7  59.115385   8.941935  83.903226
# 3      8  59.961538   8.793548  83.967742
# 4      9  31.448276  10.180000  76.900000

# %%
air.groupby(['Month'], as_index=False)[['Ozone', 'Wind', 'Temp']].agg(['max', 'min', 'mean', 'std'])
# Out:
#   Month  Ozone                              Wind                            \
#            max   min       mean        std   max  min       mean       std
# 0     5  115.0   1.0  23.615385  22.224449  20.1  5.7  11.622581  3.531450
# 1     6   71.0  12.0  29.444444  18.207904  20.7  1.7  10.266667  3.769234
# 2     7  135.0   7.0  59.115385  31.635837  14.9  4.1   8.941935  3.035981
# 3     8  168.0   9.0  59.961538  39.681210  15.5  2.3   8.793548  3.225930
# 4     9   96.0   7.0  31.448276  24.141822  16.6  2.8  10.180000  3.461254
#
#   Temp
#    max min       mean       std
# 0   81  56  65.548387  6.854870
# 1   93  65  79.100000  6.598589
# 2   92  73  83.903226  4.315513
# 3   97  72  83.967742  6.585256
# 4   93  63  76.900000  8.355671

# %% [markdown]
# ### (4) 복습문제

# %% [markdown]
# [문1] pandas 라이브러리를 pd 별칭을 주어 불러오세요.

# %%
# 라이브러리 불러오기
import pandas as pd

# %% [markdown]
# [문2] read_csv() 함수를 사용해 다음 경로의 파일을 불러와 **titanic** 데이터프레임을 만드세요.
#
# - 파일 경로: 'https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic_simple.csv'

# %% [markdown]
# **[titanic_simple 데이터 셋 정보]**
#
# - PassengerId : 승객번호
# - Survived : 생존여부(1:생존, 0:사망)
# - Pclass : 객실등급(1:1등급, 2:2등급, 3:3등급)
# - Name : 승객이름
# - Sex : 성별(male, female)
# - Age : 나이
# - Fare : 운임($)
# - Embarked : 승선지역(Southhampton, Cherbourg, Queenstown)

# %%
# 파일 읽어오기
file_url = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic_simple.csv'
titanic = pd.read_csv(file_url)

# %% [markdown]
# [문3] Fare의 중앙값을 확인해 봅시다.

# %%
titanic['Fare'].median()

# %% [markdown]
# [문4] 승선지역(Embarked)별 평균 운임(Fare)을 구해 봅시다.

# %%
titanic.groupby(['Embarked'])['Fare'].mean()
# Out:
# Embarked
# Cherbourg      59.954144
# Queenstown     13.276030
# Southampton    27.079812
# Name: Fare, dtype: float64

# %% [markdown]
# [문5] 승선지역(Embarked)별, 성별(Sex)별 평균 운임(Fare)과 평균 나이(Age)를 tmp에 저장하고 조회하시오.

# %%
tmp = titanic.groupby(['Embarked', 'Sex'])[['Fare', 'Age']].mean()
tmp
# Out:
#                          Fare        Age
# Embarked    Sex
# Cherbourg   female  75.169805  28.344262
#             male    48.262109  32.998841
# Queenstown  female  12.634958  24.291667
#             male    13.838922  30.937500
# Southampton female  38.740929  27.771505
#             male    21.711996  30.291440

# %% [markdown]
# [문6] 5번의 결과로 부터 파악할 수 있는 내용은 무엇인가요?

# %%
# Cherbourg와 Southampton에서 여성의 평균 운임이 남성보다 높으며, 모든 항구에서 남성의 평균 나이가 여성보다 높다.

# %% [markdown]
# [문7] 객실등급(Pclass)별, 생존여부(Survived)별 나이(Age), 운임(Fare)의 최대, 최소, 평균, 표준편차를 tmp에 저장하고 조회하시오.

# %%
tmp = titanic.groupby(['Pclass', 'Survived'])[['Age', 'Fare']].agg(['max', 'min', 'mean', 'std'])
tmp
# Out:
#                   Age                                   Fare           \
#                   max    min       mean        std       max      min
# Pclass Survived
# 1      0         71.0   2.00  43.695312  15.284243  263.0000   0.0000
#        1         80.0   0.92  35.368197  13.760017  512.3292  25.9292
# 2      0         70.0  16.00  33.544444  12.151581   73.5000   0.0000
#        1         62.0   0.67  25.901566  14.837787   65.0000  10.5000
# 3      0         74.0   1.00  26.555556  12.334882   69.5500   0.0000
#        1         63.0   0.42  20.646118  11.995047   56.4958   0.0000
#
#
#                       mean        std
# Pclass Survived
# 1      0         64.684007  60.662089
#        1         95.608029  85.286820
# 2      0         19.412328  15.307175
#        1         22.055700  10.853502
# 3      0         13.669364  12.118338
#        1         13.694887  10.692993
