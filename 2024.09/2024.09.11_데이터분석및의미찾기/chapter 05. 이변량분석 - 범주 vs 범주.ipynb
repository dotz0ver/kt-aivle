# %% [markdown]
# # **이변량분석 : 범주 vs 범주**

# %% [markdown]
# ## **1.환경준비**

# %% [markdown]
# * 라이브러리 불러오기

# %%
https://github.com/yongmin21/kt_aivle/blob/main/2024.09.12%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%20%EB%B0%8F%20%EC%9D%98%EB%AF%B8%20%EC%B0%BE%EA%B8%B0%202/chapter%2005.%20%EC%9D%B4%EB%B3%80%EB%9F%89%EB%B6%84%EC%84%9D%20-%20%EB%B2%94%EC%A3%BC%20vs%20%EB%B2%94%EC%A3%BC.ipynb
# Out:
#   File "<ipython-input-1-c4ba8be6b454>", line 1
#     https://github.com/yongmin21/kt_aivle/blob/main/2024.09.12%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%20%EB%B0%8F%20%EC%9D%98%EB%AF%B8%20%EC%B0%BE%EA%B8%B0%202/chapter%2005.%20%EC%9D%B4%EB%B3%80%EB%9F%89%EB%B6%84%EC%84%9D%20-%20%EB%B2%94%EC%A3%BC%20vs%20%EB%B2%94%EC%A3%BC.ipynb
#                                                                      ^
# SyntaxError: invalid decimal literal

# %%
import pandas as pd
import numpy as np
import random as rd

import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.mosaicplot import mosaic      #mosaic plot!

import scipy.stats as spst

# %% [markdown]
# * 데이터 불러오기 : 다음의 예제 데이터를 사용합니다.
# > 타이타닉 생존자

# %%
# 타이타닉 데이터
titanic = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic.1.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass Title     Sex   Age  SibSp  Parch  \
# 0            1         0       3    Mr    male  22.0      1      0
# 1            2         1       1   Mrs  female  38.0      1      0
# 2            3         1       3  Miss  female  26.0      0      0
# 3            4         1       1   Mrs  female  35.0      1      0
# 4            5         0       3    Mr    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked AgeGroup  Family  Mother    Fare2
# 0         A/5 21171   7.2500   NaN        S   Age_20       2       0   7.2500
# 1          PC 17599  71.2833   C85        C   Age_30       2       0  71.2833
# 2  STON/O2. 3101282   7.9250   NaN        S   Age_20       1       0   7.9250
# 3            113803  53.1000  C123        S   Age_30       2       0  53.1000
# 4            373450   8.0500   NaN        S   Age_30       1       0   8.0500

# %% [markdown]
# ## **2.범주 --> 범주**

# %% [markdown]
# ### **(1) 교차표(pd.crosstab)**
#
# 범주 vs 범주 를 비교하고 분석하기 위해서는 먼저 **교차표**를 만들어야 합니다.

# %% [markdown]
# * pd.crosstab(행, 열)

# %%
# 두 범주별 빈도수를 교차표로 만들어 봅시다.
pd.crosstab(titanic['Survived'], titanic['Sex'])
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %% [markdown]
# * pd.crosstab(행, 열, normalize =   )
#
# <img src='https://github.com/DA4BAM/image/blob/main/crosstab.png?raw=true' width=700/>

# %%
pd.crosstab(titanic['Survived'], titanic['Sex'], normalize = 'columns')
# Out:
# Sex         female      male
# Survived
# 0         0.257962  0.811092
# 1         0.742038  0.188908

# %%
pd.crosstab(titanic['Survived'], titanic['Sex'], normalize = 'index')
# Out:
# Sex         female      male
# Survived
# 0         0.147541  0.852459
# 1         0.681287  0.318713

# %%
pd.crosstab(titanic['Survived'], titanic['Embarked'], normalize = 'all')
# Out:
# Embarked         C        Q         S
# Survived
# 0         0.084175  0.05275  0.479237
# 1         0.104377  0.03367  0.245791

# %% [markdown]
# ### **(2) 시각화**
# * mosaic
# * (참조) 100% Stacked Bar

# %% [markdown]
# 1) Pclass --> Survived

# %% [markdown]
# * mosaic plot
#     * mosaic(dataframe, [ feature, target])

# %%
mosaic(titanic, ['Sex','Survived'])
plt.axhline(1- titanic['Survived'].mean(), color = 'r')
plt.show()

# %%
# Pclass별 생존여부를 mosaic plot으로 그려 봅시다.
mosaic(titanic, [ 'Pclass','Survived'])
plt.axhline(1- titanic['Survived'].mean(), color = 'r')
plt.show()

# %% [markdown]
# ① X축 길이는 각 객실등급별 승객비율을 나타냅니다.
# ② 그 중 3등급 객실에 대해서 보면, y축의 길이는, 3등급 객실 승객 중에서 사망, 생존 비율을 의미합니다.

# %% [markdown]
# * 100% Stacked Bar
#     * 먼저 crosstab으로 집계 : pd.crosstab(**feature**, **target**, normalize = **'index'**)
#     * .plot.bar(stacked = true)
#     * 전체 평균선 : plt.axhline()

# %%
temp = pd.crosstab(titanic['Pclass'], titanic['Survived'], normalize = 'index')
print(temp)
temp.plot.bar(stacked=True)
plt.axhline(1-titanic['Survived'].mean(), color = 'r')
plt.show()
# Out:
# Survived         0         1
# Pclass
# 1         0.370370  0.629630
# 2         0.527174  0.472826
# 3         0.757637  0.242363

# %% [markdown]
# 비율만 비교하므로 양에 대한 비교는 할 수 없다!

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# 아래 관계에 대해서 교차표와 시각화(mosaic)를 수행하고, feature와 target 간에 관계가 있는지 분석해 봅시다.

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass Title     Sex   Age  SibSp  Parch  \
# 0            1         0       3    Mr    male  22.0      1      0
# 1            2         1       1   Mrs  female  38.0      1      0
# 2            3         1       3  Miss  female  26.0      0      0
# 3            4         1       1   Mrs  female  35.0      1      0
# 4            5         0       3    Mr    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked AgeGroup  Family  Mother    Fare2
# 0         A/5 21171   7.2500   NaN        S   Age_20       2       0   7.2500
# 1          PC 17599  71.2833   C85        C   Age_30       2       0  71.2833
# 2  STON/O2. 3101282   7.9250   NaN        S   Age_20       1       0   7.9250
# 3            113803  53.1000  C123        S   Age_30       2       0  53.1000
# 4            373450   8.0500   NaN        S   Age_30       1       0   8.0500

# %% [markdown]
# * [문1] Sex --> Survived

# %%
pd.crosstab(titanic['Survived'], titanic['Sex'])
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
mosaic(titanic, ['Sex','Survived'])
plt.axhline(1- titanic['Survived'].mean(), color = 'r')
plt.show()

# %% [markdown]
# * [문2] Embarked --> Survived

# %%
pd.crosstab(titanic['Survived'], titanic['Embarked'])
# Out:
# Embarked   C   Q    S
# Survived
# 0         75  47  427
# 1         93  30  219

# %%
# plt.rcParams["figure.figsize"]=(8, 6)
mosaic(titanic, ['Embarked','Survived'])
plt.axhline(1- titanic['Survived'].mean(), color = 'r')
plt.show()

# %% [markdown]
# * [문3] Title --> Survived

# %%
pd.crosstab(titanic['Survived'], titanic['Title'])
# Out:
# Title     Master  Miss   Mr  Mrs  Others
# Survived
# 0             18    55  439   26      11
# 1             23   130   84  102       3

# %%
plt.rcParams["figure.figsize"]=(6.4, 4.4) # 이 노트북 커널의 기본 설정 값으로 지정
mosaic(titanic, ['Title','Survived'], gap=0.003)
plt.axhline(1- titanic['Survived'].mean(), color = 'r')
plt.show()

# %%
mosaic(titanic, ['Title','Survived'], gap=0.003)
plt.axhline(1- titanic['Survived'].mean(), color = 'r')
plt.show()

# %% [markdown]
# ### **(3) 수치화 : 카이제곱검정**

# %% [markdown]
# * 카이제곱검정 : 범주형 변수들 사이에 어떤 관계가 있는지, 수치화 하는 방법

# %% [markdown]
# ![image.png](https://github.com/DA4BAM/image/blob/main/%EC%B9%B4%EC%9D%B4%EC%A0%9C%EA%B3%B1%20%ED%86%B5%EA%B3%84%EB%9F%89.png?raw=true)

# %% [markdown]
# * 카이 제곱 통계량은
#     * 클수록 기대빈도로부터 실제 값에 차이가 크다는 의미.
#     * 계산식으로 볼 때, 범주의 수가 늘어날 수록 값은 커지게 되어 있음.
#     * 보통, 자유도의 2~3배 보다 크면, 차이가 있다고 본다.
#
# * 범주형 변수의 자유도 : 범주의 수 - 1
#
# * 카이제곱검정에서는
#     * x 변수의 자유도 × y 변수의 자유도
#     * 예 : Pclass --> Survived
#         * Pclass : 범주가 3개, Survived : 2개
#         * (3-1) * (2-1) = 2
#         * 그러므로, 2의 2 ~ 3배인 4 ~ 6 보다 카이제곱 통계량이 크면, 차이가 있다고 볼수 있음.

# %% [markdown]
# * 타이타닉 데이터에서 객실등급과 생존여부 간의 카이제곱 검정을 수행해 봅시다.

# %%
pd.crosstab(titanic['Survived'], titanic['Pclass'])
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %%
# 1) 먼저 교차표 집계
table = pd.crosstab(titanic['Survived'], titanic['Pclass'])
print(table)
print('-' * 50)

# 2) 카이제곱검정
spst.chi2_contingency(table)
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119
# --------------------------------------------------
# Chi2ContingencyResult(statistic=102.88898875696056, pvalue=4.549251711298793e-23, dof=2, expected_freq=array([[133.09090909, 113.37373737, 302.53535354],
#        [ 82.90909091,  70.62626263, 188.46464646]]))

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# 다음의 관계에 대해 수치화 해 봅시다.

# %% [markdown]
# * [문1] Sex --> Survived

# %%
# 1) 먼저 교차표 집계
table = pd.crosstab(titanic['Survived'], titanic['Sex'])
print(table)
print('-' * 50)

# 2) 카이제곱검정
spst.chi2_contingency(table)
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109
# --------------------------------------------------
# Chi2ContingencyResult(statistic=260.71702016732104, pvalue=1.1973570627755645e-58, dof=1, expected_freq=array([[193.47474747, 355.52525253],
#        [120.52525253, 221.47474747]]))

# %% [markdown]
# * [문2] Embarked --> Survived

# %%
# 1) 먼저 교차표 집계
table = pd.crosstab(titanic['Survived'], titanic['Embarked'])
print(table)
print('-' * 50)

# 2) 카이제곱검정
spst.chi2_contingency(table)
# Out:
# Embarked   C   Q    S
# Survived
# 0         75  47  427
# 1         93  30  219
# --------------------------------------------------
# Chi2ContingencyResult(statistic=25.964452881874784, pvalue=2.3008626481449577e-06, dof=2, expected_freq=array([[103.51515152,  47.44444444, 398.04040404],
#        [ 64.48484848,  29.55555556, 247.95959596]]))

# %% [markdown]
# * [문3] Title --> Survived

# %%
# 1) 먼저 교차표 집계
table = pd.crosstab(titanic['Survived'], titanic['Title'])
print(table)
print('-' * 50)

# 2) 카이제곱검정
spst.chi2_contingency(table)
# Out:
# Title     Master  Miss   Mr  Mrs  Others
# Survived
# 0             18    55  439   26      11
# 1             23   130   84  102       3
# --------------------------------------------------
# Chi2ContingencyResult(statistic=289.1953165452417, pvalue=2.318405007221846e-61, dof=4, expected_freq=array([[ 25.26262626, 113.98989899, 322.25252525,  78.86868687,
#           8.62626263],
#        [ 15.73737374,  71.01010101, 200.74747475,  49.13131313,
#           5.37373737]]))
